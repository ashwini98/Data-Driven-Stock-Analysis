# %%
# %pip install pandas
# Out:
# Requirement already satisfied: pandas in d:\myproject2\demo\lib\site-packages (2.2.3)
# Requirement already satisfied: numpy>=1.26.0 in d:\myproject2\demo\lib\site-packages (from pandas) (2.2.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in d:\myproject2\demo\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in d:\myproject2\demo\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in d:\myproject2\demo\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: six>=1.5 in d:\myproject2\demo\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.3.1 -> 25.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# %pip install pyyaml
# Out:
# Requirement already satisfied: pyyaml in d:\myproject2\demo\lib\site-packages (6.0.2)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.3.1 -> 25.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# %pip install matplotlib
# Out:
# Requirement already satisfied: matplotlib in d:\myproject2\demo\lib\site-packages (3.10.1)
# Requirement already satisfied: contourpy>=1.0.1 in d:\myproject2\demo\lib\site-packages (from matplotlib) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in d:\myproject2\demo\lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in d:\myproject2\demo\lib\site-packages (from matplotlib) (4.57.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in d:\myproject2\demo\lib\site-packages (from matplotlib) (1.4.8)
# Requirement already satisfied: numpy>=1.23 in d:\myproject2\demo\lib\site-packages (from matplotlib) (2.2.4)
# Requirement already satisfied: packaging>=20.0 in d:\myproject2\demo\lib\site-packages (from matplotlib) (24.2)
# Requirement already satisfied: pillow>=8 in d:\myproject2\demo\lib\site-packages (from matplotlib) (11.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in d:\myproject2\demo\lib\site-packages (from matplotlib) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in d:\myproject2\demo\lib\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in d:\myproject2\demo\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.3.1 -> 25.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# %pip install seaborn
# Out:
# Requirement already satisfied: seaborn in d:\myproject2\demo\lib\site-packages (0.13.2)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in d:\myproject2\demo\lib\site-packages (from seaborn) (2.2.4)
# Requirement already satisfied: pandas>=1.2 in d:\myproject2\demo\lib\site-packages (from seaborn) (2.2.3)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in d:\myproject2\demo\lib\site-packages (from seaborn) (3.10.1)
# Requirement already satisfied: contourpy>=1.0.1 in d:\myproject2\demo\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in d:\myproject2\demo\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in d:\myproject2\demo\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (4.57.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in d:\myproject2\demo\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in d:\myproject2\demo\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (24.2)
# Requirement already satisfied: pillow>=8 in d:\myproject2\demo\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (11.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in d:\myproject2\demo\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in d:\myproject2\demo\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in d:\myproject2\demo\lib\site-packages (from pandas>=1.2->seaborn) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in d:\myproject2\demo\lib\site-packages (from pandas>=1.2->seaborn) (2025.2)
# Requirement already satisfied: six>=1.5 in d:\myproject2\demo\lib\site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.4->seaborn) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.3.1 -> 25.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import os
import pandas as pd
import yaml
import numpy as np

# Initialize an empty DataFrame to store all the data:
wholedf = pd.DataFrame()

# Define paths in list:
path = ["2023-10", "2023-11", "2023-12", "2024-01", "2024-02", "2024-03", "2024-04", "2024-05", "2024-06", "2024-07", "2024-08", "2024-09", "2024-10", "2024-11"]

# Define the dates range:
path_date = pd.date_range("2023-10-03 05:30:00", "2024-11-22 05:30:00", freq='D').strftime('%Y-%m-%d_%H-%M-%S').tolist()

# Iterate over the paths:
for i in path:
    for j in path_date:
        # File path: yaml file name:
        file_path = f"D:/data/{i}/{j}.yaml"

        # Check if the file exists before trying to read it:
        if os.path.exists(file_path):
            try:
                # Open the file and load its content
                with open(file_path, 'r') as file:
                    data = yaml.safe_load(file)  # Load the YAML file

                    # Check if the data is not empty
                    if data:
                        # Convert the loaded data to a DataFrame and concatenate it
                        df = pd.DataFrame(data)
                        wholedf = pd.concat([wholedf, df], ignore_index=True)
            except yaml.YAMLError as e:
                print(f"Error loading YAML file {file_path}: {e}")
        else:
            print(f"File not found: {file_path}")

# Print the first 5 rows of the concatenated DataFrame:
print(wholedf.head())

# Save the concatenated DataFrame to a CSV file:
wholedf.to_csv("Combined_Data.csv", index=False)

# Ticker-wise data extraction:
tickers_df = pd.DataFrame(wholedf['Ticker'].unique(), columns=['Ticker'])

# Iterate over each unique ticker
for ticker in tickers_df['Ticker']:
    
    # Filter the DataFrame for the current ticker and save it to CSV
    wholedf[wholedf['Ticker'] == ticker].to_csv(f"D:/TickerWise/{ticker}.csv", index=False)
# Out:
# File not found: D:/data/2023-10/2023-10-07_05-30-00.yaml
# File not found: D:/data/2023-10/2023-10-08_05-30-00.yaml
# File not found: D:/data/2023-10/2023-10-14_05-30-00.yaml
# File not found: D:/data/2023-10/2023-10-15_05-30-00.yaml
# File not found: D:/data/2023-10/2023-10-21_05-30-00.yaml
# File not found: D:/data/2023-10/2023-10-22_05-30-00.yaml
# File not found: D:/data/2023-10/2023-10-24_05-30-00.yaml
# File not found: D:/data/2023-10/2023-10-28_05-30-00.yaml
# File not found: D:/data/2023-10/2023-10-29_05-30-00.yaml
# File not found: D:/data/2023-10/2023-11-01_05-30-00.yaml
# File not found: D:/data/2023-10/2023-11-02_05-30-00.yaml
# File not found: D:/data/2023-10/2023-11-03_05-30-00.yaml
# File not found: D:/data/2023-10/2023-11-04_05-30-00.yaml
# File not found: D:/data/2023-10/2023-11-05_05-30-00.yaml
# File not found: D:/data/2023-10/2023-11-06_05-30-00.yaml
# File not found: D:/data/2023-10/2023-11-07_05-30-00.yaml
# File not found: D:/data/2023-10/2023-11-08_05-30-00.yaml
# File not found: D:/data/2023-10/2023-11-09_05-30-00.yaml
# File not found: D:/data/2023-10/2023-11-10_05-30-00.yaml
# File not found: D:/data/2023-10/2023-11-11_05-30-00.yaml
# File not found: D:/data/2023-10/2023-11-12_05-30-00.yaml
# File not found: D:/data/2023-10/2023-11-13_05-30-00.yaml
# File not found: D:/data/2023-10/2023-11-14_05-30-00.yaml
# File not found: D:/data/2023-10/2023-11-15_05-30-00.yaml
# File not found: D:/data/2023-10/2023-11-16_05-30-00.yaml
# File not found: D:/data/2023-10/2023-11-17_05-30-00.yaml
# File not found: D:/data/2023-10/2023-11-18_05-30-00.yaml
# File not found: D:/data/2023-10/2023-11-19_05-30-00.yaml
# File not found: D:/data/2023-10/2023-11-20_05-30-00.yaml
# File not found: D:/data/2023-10/2023-11-21_05-30-00.yaml
# File not found: D:/data/2023-10/2023-11-22_05-30-00.yaml
# File not found: D:/data/2023-10/2023-11-23_05-30-00.yaml
# File not found: D:/data/2023-10/2023-11-24_05-30-00.yaml
# File not found: D:/data/2023-10/2023-11-25_05-30-00.yaml
# File not found: D:/data/2023-10/2023-11-26_05-30-00.yaml
# File not found: D:/data/2023-10/2023-11-27_05-30-00.yaml
# File not found: D:/data/2023-10/2023-11-28_05-30-00.yaml
# File not found: D:/data/2023-10/2023-11-29_05-30-00.yaml
# File not found: D:/data/2023-10/2023-11-30_05-30-00.yaml
# File not found: D:/data/2023-10/2023-12-01_05-30-00.yaml
# File not found: D:/data/2023-10/2023-12-02_05-30-00.yaml
# File not found: D:/data/2023-10/2023-12-03_05-30-00.yaml
# File not found: D:/data/2023-10/2023-12-04_05-30-00.yaml
# File not found: D:/data/2023-10/2023-12-05_05-30-00.yaml
# File not found: D:/data/2023-10/2023-12-06_05-30-00.yaml
# File not found: D:/data/2023-10/2023-12-07_05-30-00.yaml
# File not found: D:/data/2023-10/2023-12-08_05-30-00.yaml
# File not found: D:/data/2023-10/2023-12-09_05-30-00.yaml
# File not found: D:/data/2023-10/2023-12-10_05-30-00.yaml
# File not found: D:/data/2023-10/2023-12-11_05-30-00.yaml
# File not found: D:/data/2023-10/2023-12-12_05-30-00.yaml
# File not found: D:/data/2023-10/2023-12-13_05-30-00.yaml
# File not found: D:/data/2023-10/2023-12-14_05-30-00.yaml
# File not found: D:/data/2023-10/2023-12-15_05-30-00.yaml
# File not found: D:/data/2023-10/2023-12-16_05-30-00.yaml
# File not found: D:/data/2023-10/2023-12-17_05-30-00.yaml
# File not found: D:/data/2023-10/2023-12-18_05-30-00.yaml
# File not found: D:/data/2023-10/2023-12-19_05-30-00.yaml
# File not found: D:/data/2023-10/2023-12-20_05-30-00.yaml
# File not found: D:/data/2023-10/2023-12-21_05-30-00.yaml
# File not found: D:/data/2023-10/2023-12-22_05-30-00.yaml
# File not found: D:/data/2023-10/2023-12-23_05-30-00.yaml
# File not found: D:/data/2023-10/2023-12-24_05-30-00.yaml
# File not found: D:/data/2023-10/2023-12-25_05-30-00.yaml
# File not found: D:/data/2023-10/2023-12-26_05-30-00.yaml
# File not found: D:/data/2023-10/2023-12-27_05-30-00.yaml
# File not found: D:/data/2023-10/2023-12-28_05-30-00.yaml
# File not found: D:/data/2023-10/2023-12-29_05-30-00.yaml
# File not found: D:/data/2023-10/2023-12-30_05-30-00.yaml
# File not found: D:/data/2023-10/2023-12-31_05-30-00.yaml
# File not found: D:/data/2023-10/2024-01-01_05-30-00.yaml
# File not found: D:/data/2023-10/2024-01-02_05-30-00.yaml
# File not found: D:/data/2023-10/2024-01-03_05-30-00.yaml
# File not found: D:/data/2023-10/2024-01-04_05-30-00.yaml
# File not found: D:/data/2023-10/2024-01-05_05-30-00.yaml
# File not found: D:/data/2023-10/2024-01-06_05-30-00.yaml
# File not found: D:/data/2023-10/2024-01-07_05-30-00.yaml
# File not found: D:/data/2023-10/2024-01-08_05-30-00.yaml
# File not found: D:/data/2023-10/2024-01-09_05-30-00.yaml
# File not found: D:/data/2023-10/2024-01-10_05-30-00.yaml
# File not found: D:/data/2023-10/2024-01-11_05-30-00.yaml
# File not found: D:/data/2023-10/2024-01-12_05-30-00.yaml
# File not found: D:/data/2023-10/2024-01-13_05-30-00.yaml
# File not found: D:/data/2023-10/2024-01-14_05-30-00.yaml
# File not found: D:/data/2023-10/2024-01-15_05-30-00.yaml
# File not found: D:/data/2023-10/2024-01-16_05-30-00.yaml
# File not found: D:/data/2023-10/2024-01-17_05-30-00.yaml
# File not found: D:/data/2023-10/2024-01-18_05-30-00.yaml
# File not found: D:/data/2023-10/2024-01-19_05-30-00.yaml
# File not found: D:/data/2023-10/2024-01-20_05-30-00.yaml
# File not found: D:/data/2023-10/2024-01-21_05-30-00.yaml
# File not found: D:/data/2023-10/2024-01-22_05-30-00.yaml
# File not found: D:/data/2023-10/2024-01-23_05-30-00.yaml
# File not found: D:/data/2023-10/2024-01-24_05-30-00.yaml
# File not found: D:/data/2023-10/2024-01-25_05-30-00.yaml
# File not found: D:/data/2023-10/2024-01-26_05-30-00.yaml
# File not found: D:/data/2023-10/2024-01-27_05-30-00.yaml
# File not found: D:/data/2023-10/2024-01-28_05-30-00.yaml
# File not found: D:/data/2023-10/2024-01-29_05-30-00.yaml
# File not found: D:/data/2023-10/2024-01-30_05-30-00.yaml
# File not found: D:/data/2023-10/2024-01-31_05-30-00.yaml
# File not found: D:/data/2023-10/2024-02-01_05-30-00.yaml
# File not found: D:/data/2023-10/2024-02-02_05-30-00.yaml
# File not found: D:/data/2023-10/2024-02-03_05-30-00.yaml
# File not found: D:/data/2023-10/2024-02-04_05-30-00.yaml
# File not found: D:/data/2023-10/2024-02-05_05-30-00.yaml
# File not found: D:/data/2023-10/2024-02-06_05-30-00.yaml
# File not found: D:/data/2023-10/2024-02-07_05-30-00.yaml
# File not found: D:/data/2023-10/2024-02-08_05-30-00.yaml
# File not found: D:/data/2023-10/2024-02-09_05-30-00.yaml
# File not found: D:/data/2023-10/2024-02-10_05-30-00.yaml
# File not found: D:/data/2023-10/2024-02-11_05-30-00.yaml
# File not found: D:/data/2023-10/2024-02-12_05-30-00.yaml
# File not found: D:/data/2023-10/2024-02-13_05-30-00.yaml
# File not found: D:/data/2023-10/2024-02-14_05-30-00.yaml
# File not found: D:/data/2023-10/2024-02-15_05-30-00.yaml
# File not found: D:/data/2023-10/2024-02-16_05-30-00.yaml
# File not found: D:/data/2023-10/2024-02-17_05-30-00.yaml
# File not found: D:/data/2023-10/2024-02-18_05-30-00.yaml
# File not found: D:/data/2023-10/2024-02-19_05-30-00.yaml
# File not found: D:/data/2023-10/2024-02-20_05-30-00.yaml
# File not found: D:/data/2023-10/2024-02-21_05-30-00.yaml
# File not found: D:/data/2023-10/2024-02-22_05-30-00.yaml
# File not found: D:/data/2023-10/2024-02-23_05-30-00.yaml
# File not found: D:/data/2023-10/2024-02-24_05-30-00.yaml
# File not found: D:/data/2023-10/2024-02-25_05-30-00.yaml
# File not found: D:/data/2023-10/2024-02-26_05-30-00.yaml
# File not found: D:/data/2023-10/2024-02-27_05-30-00.yaml
# File not found: D:/data/2023-10/2024-02-28_05-30-00.yaml
# File not found: D:/data/2023-10/2024-02-29_05-30-00.yaml
# File not found: D:/data/2023-10/2024-03-01_05-30-00.yaml
# File not found: D:/data/2023-10/2024-03-02_05-30-00.yaml
# File not found: D:/data/2023-10/2024-03-03_05-30-00.yaml
# File not found: D:/data/2023-10/2024-03-04_05-30-00.yaml
# File not found: D:/data/2023-10/2024-03-05_05-30-00.yaml
# File not found: D:/data/2023-10/2024-03-06_05-30-00.yaml
# File not found: D:/data/2023-10/2024-03-07_05-30-00.yaml
# File not found: D:/data/2023-10/2024-03-08_05-30-00.yaml
# File not found: D:/data/2023-10/2024-03-09_05-30-00.yaml
# File not found: D:/data/2023-10/2024-03-10_05-30-00.yaml
# File not found: D:/data/2023-10/2024-03-11_05-30-00.yaml
# File not found: D:/data/2023-10/2024-03-12_05-30-00.yaml
# File not found: D:/data/2023-10/2024-03-13_05-30-00.yaml
# File not found: D:/data/2023-10/2024-03-14_05-30-00.yaml
# File not found: D:/data/2023-10/2024-03-15_05-30-00.yaml
# File not found: D:/data/2023-10/2024-03-16_05-30-00.yaml
# File not found: D:/data/2023-10/2024-03-17_05-30-00.yaml
# File not found: D:/data/2023-10/2024-03-18_05-30-00.yaml
# File not found: D:/data/2023-10/2024-03-19_05-30-00.yaml
# File not found: D:/data/2023-10/2024-03-20_05-30-00.yaml
# File not found: D:/data/2023-10/2024-03-21_05-30-00.yaml
# File not found: D:/data/2023-10/2024-03-22_05-30-00.yaml
# File not found: D:/data/2023-10/2024-03-23_05-30-00.yaml
# File not found: D:/data/2023-10/2024-03-24_05-30-00.yaml
# File not found: D:/data/2023-10/2024-03-25_05-30-00.yaml
# File not found: D:/data/2023-10/2024-03-26_05-30-00.yaml
# File not found: D:/data/2023-10/2024-03-27_05-30-00.yaml
# File not found: D:/data/2023-10/2024-03-28_05-30-00.yaml
# File not found: D:/data/2023-10/2024-03-29_05-30-00.yaml
# File not found: D:/data/2023-10/2024-03-30_05-30-00.yaml
# File not found: D:/data/2023-10/2024-03-31_05-30-00.yaml
# File not found: D:/data/2023-10/2024-04-01_05-30-00.yaml
# File not found: D:/data/2023-10/2024-04-02_05-30-00.yaml
# File not found: D:/data/2023-10/2024-04-03_05-30-00.yaml
# File not found: D:/data/2023-10/2024-04-04_05-30-00.yaml
# File not found: D:/data/2023-10/2024-04-05_05-30-00.yaml
# File not found: D:/data/2023-10/2024-04-06_05-30-00.yaml
# File not found: D:/data/2023-10/2024-04-07_05-30-00.yaml
# File not found: D:/data/2023-10/2024-04-08_05-30-00.yaml
# File not found: D:/data/2023-10/2024-04-09_05-30-00.yaml
# File not found: D:/data/2023-10/2024-04-10_05-30-00.yaml
# File not found: D:/data/2023-10/2024-04-11_05-30-00.yaml
# File not found: D:/data/2023-10/2024-04-12_05-30-00.yaml
# File not found: D:/data/2023-10/2024-04-13_05-30-00.yaml
# File not found: D:/data/2023-10/2024-04-14_05-30-00.yaml
# File not found: D:/data/2023-10/2024-04-15_05-30-00.yaml
# File not found: D:/data/2023-10/2024-04-16_05-30-00.yaml
# File not found: D:/data/2023-10/2024-04-17_05-30-00.yaml
# File not found: D:/data/2023-10/2024-04-18_05-30-00.yaml
# File not found: D:/data/2023-10/2024-04-19_05-30-00.yaml
# File not found: D:/data/2023-10/2024-04-20_05-30-00.yaml
# File not found: D:/data/2023-10/2024-04-21_05-30-00.yaml
# File not found: D:/data/2023-10/2024-04-22_05-30-00.yaml
# File not found: D:/data/2023-10/2024-04-23_05-30-00.yaml
# File not found: D:/data/2023-10/2024-04-24_05-30-00.yaml
# File not found: D:/data/2023-10/2024-04-25_05-30-00.yaml
# File not found: D:/data/2023-10/2024-04-26_05-30-00.yaml
# File not found: D:/data/2023-10/2024-04-27_05-30-00.yaml
# File not found: D:/data/2023-10/2024-04-28_05-30-00.yaml
# File not found: D:/data/2023-10/2024-04-29_05-30-00.yaml
# File not found: D:/data/2023-10/2024-04-30_05-30-00.yaml
# File not found: D:/data/2023-10/2024-05-01_05-30-00.yaml
# File not found: D:/data/2023-10/2024-05-02_05-30-00.yaml
# File not found: D:/data/2023-10/2024-05-03_05-30-00.yaml
# File not found: D:/data/2023-10/2024-05-04_05-30-00.yaml
# File not found: D:/data/2023-10/2024-05-05_05-30-00.yaml
# File not found: D:/data/2023-10/2024-05-06_05-30-00.yaml
# File not found: D:/data/2023-10/2024-05-07_05-30-00.yaml
# File not found: D:/data/2023-10/2024-05-08_05-30-00.yaml
# File not found: D:/data/2023-10/2024-05-09_05-30-00.yaml
# File not found: D:/data/2023-10/2024-05-10_05-30-00.yaml
# File not found: D:/data/2023-10/2024-05-11_05-30-00.yaml
# File not found: D:/data/2023-10/2024-05-12_05-30-00.yaml
# File not found: D:/data/2023-10/2024-05-13_05-30-00.yaml
# File not found: D:/data/2023-10/2024-05-14_05-30-00.yaml
# File not found: D:/data/2023-10/2024-05-15_05-30-00.yaml
# File not found: D:/data/2023-10/2024-05-16_05-30-00.yaml
# File not found: D:/data/2023-10/2024-05-17_05-30-00.yaml
# File not found: D:/data/2023-10/2024-05-18_05-30-00.yaml
# File not found: D:/data/2023-10/2024-05-19_05-30-00.yaml
# File not found: D:/data/2023-10/2024-05-20_05-30-00.yaml
# File not found: D:/data/2023-10/2024-05-21_05-30-00.yaml
# File not found: D:/data/2023-10/2024-05-22_05-30-00.yaml
# File not found: D:/data/2023-10/2024-05-23_05-30-00.yaml
# File not found: D:/data/2023-10/2024-05-24_05-30-00.yaml
# File not found: D:/data/2023-10/2024-05-25_05-30-00.yaml
# File not found: D:/data/2023-10/2024-05-26_05-30-00.yaml
# File not found: D:/data/2023-10/2024-05-27_05-30-00.yaml
# File not found: D:/data/2023-10/2024-05-28_05-30-00.yaml
# File not found: D:/data/2023-10/2024-05-29_05-30-00.yaml
# File not found: D:/data/2023-10/2024-05-30_05-30-00.yaml
# File not found: D:/data/2023-10/2024-05-31_05-30-00.yaml
# File not found: D:/data/2023-10/2024-06-01_05-30-00.yaml
# File not found: D:/data/2023-10/2024-06-02_05-30-00.yaml
# File not found: D:/data/2023-10/2024-06-03_05-30-00.yaml
# File not found: D:/data/2023-10/2024-06-04_05-30-00.yaml
# File not found: D:/data/2023-10/2024-06-05_05-30-00.yaml
# File not found: D:/data/2023-10/2024-06-06_05-30-00.yaml
# File not found: D:/data/2023-10/2024-06-07_05-30-00.yaml
# File not found: D:/data/2023-10/2024-06-08_05-30-00.yaml
# File not found: D:/data/2023-10/2024-06-09_05-30-00.yaml
# File not found: D:/data/2023-10/2024-06-10_05-30-00.yaml
# File not found: D:/data/2023-10/2024-06-11_05-30-00.yaml
# File not found: D:/data/2023-10/2024-06-12_05-30-00.yaml
# File not found: D:/data/2023-10/2024-06-13_05-30-00.yaml
# File not found: D:/data/2023-10/2024-06-14_05-30-00.yaml
# File not found: D:/data/2023-10/2024-06-15_05-30-00.yaml
# File not found: D:/data/2023-10/2024-06-16_05-30-00.yaml
# File not found: D:/data/2023-10/2024-06-17_05-30-00.yaml
# File not found: D:/data/2023-10/2024-06-18_05-30-00.yaml
# File not found: D:/data/2023-10/2024-06-19_05-30-00.yaml
# File not found: D:/data/2023-10/2024-06-20_05-30-00.yaml
# File not found: D:/data/2023-10/2024-06-21_05-30-00.yaml
# File not found: D:/data/2023-10/2024-06-22_05-30-00.yaml
# File not found: D:/data/2023-10/2024-06-23_05-30-00.yaml
# File not found: D:/data/2023-10/2024-06-24_05-30-00.yaml
# File not found: D:/data/2023-10/2024-06-25_05-30-00.yaml
# File not found: D:/data/2023-10/2024-06-26_05-30-00.yaml
# File not found: D:/data/2023-10/2024-06-27_05-30-00.yaml
# File not found: D:/data/2023-10/2024-06-28_05-30-00.yaml
# File not found: D:/data/2023-10/2024-06-29_05-30-00.yaml
# File not found: D:/data/2023-10/2024-06-30_05-30-00.yaml
# File not found: D:/data/2023-10/2024-07-01_05-30-00.yaml
# File not found: D:/data/2023-10/2024-07-02_05-30-00.yaml
# File not found: D:/data/2023-10/2024-07-03_05-30-00.yaml
# File not found: D:/data/2023-10/2024-07-04_05-30-00.yaml
# File not found: D:/data/2023-10/2024-07-05_05-30-00.yaml
# File not found: D:/data/2023-10/2024-07-06_05-30-00.yaml
# File not found: D:/data/2023-10/2024-07-07_05-30-00.yaml
# File not found: D:/data/2023-10/2024-07-08_05-30-00.yaml
# File not found: D:/data/2023-10/2024-07-09_05-30-00.yaml
# File not found: D:/data/2023-10/2024-07-10_05-30-00.yaml
# File not found: D:/data/2023-10/2024-07-11_05-30-00.yaml
# File not found: D:/data/2023-10/2024-07-12_05-30-00.yaml
# File not found: D:/data/2023-10/2024-07-13_05-30-00.yaml
# File not found: D:/data/2023-10/2024-07-14_05-30-00.yaml
# File not found: D:/data/2023-10/2024-07-15_05-30-00.yaml
# File not found: D:/data/2023-10/2024-07-16_05-30-00.yaml
# File not found: D:/data/2023-10/2024-07-17_05-30-00.yaml
# File not found: D:/data/2023-10/2024-07-18_05-30-00.yaml
# File not found: D:/data/2023-10/2024-07-19_05-30-00.yaml
# File not found: D:/data/2023-10/2024-07-20_05-30-00.yaml
# File not found: D:/data/2023-10/2024-07-21_05-30-00.yaml
# File not found: D:/data/2023-10/2024-07-22_05-30-00.yaml
# File not found: D:/data/2023-10/2024-07-23_05-30-00.yaml
# File not found: D:/data/2023-10/2024-07-24_05-30-00.yaml
# File not found: D:/data/2023-10/2024-07-25_05-30-00.yaml
# File not found: D:/data/2023-10/2024-07-26_05-30-00.yaml
# File not found: D:/data/2023-10/2024-07-27_05-30-00.yaml
# File not found: D:/data/2023-10/2024-07-28_05-30-00.yaml
# File not found: D:/data/2023-10/2024-07-29_05-30-00.yaml
# File not found: D:/data/2023-10/2024-07-30_05-30-00.yaml
# File not found: D:/data/2023-10/2024-07-31_05-30-00.yaml
# File not found: D:/data/2023-10/2024-08-01_05-30-00.yaml
# File not found: D:/data/2023-10/2024-08-02_05-30-00.yaml
# File not found: D:/data/2023-10/2024-08-03_05-30-00.yaml
# File not found: D:/data/2023-10/2024-08-04_05-30-00.yaml
# File not found: D:/data/2023-10/2024-08-05_05-30-00.yaml
# File not found: D:/data/2023-10/2024-08-06_05-30-00.yaml
# File not found: D:/data/2023-10/2024-08-07_05-30-00.yaml
# File not found: D:/data/2023-10/2024-08-08_05-30-00.yaml
# File not found: D:/data/2023-10/2024-08-09_05-30-00.yaml
# File not found: D:/data/2023-10/2024-08-10_05-30-00.yaml
# File not found: D:/data/2023-10/2024-08-11_05-30-00.yaml
# File not found: D:/data/2023-10/2024-08-12_05-30-00.yaml
# File not found: D:/data/2023-10/2024-08-13_05-30-00.yaml
# File not found: D:/data/2023-10/2024-08-14_05-30-00.yaml
# File not found: D:/data/2023-10/2024-08-15_05-30-00.yaml
# File not found: D:/data/2023-10/2024-08-16_05-30-00.yaml
# File not found: D:/data/2023-10/2024-08-17_05-30-00.yaml
# File not found: D:/data/2023-10/2024-08-18_05-30-00.yaml
# File not found: D:/data/2023-10/2024-08-19_05-30-00.yaml
# File not found: D:/data/2023-10/2024-08-20_05-30-00.yaml
# File not found: D:/data/2023-10/2024-08-21_05-30-00.yaml
# File not found: D:/data/2023-10/2024-08-22_05-30-00.yaml
# File not found: D:/data/2023-10/2024-08-23_05-30-00.yaml
# File not found: D:/data/2023-10/2024-08-24_05-30-00.yaml
# File not found: D:/data/2023-10/2024-08-25_05-30-00.yaml
# File not found: D:/data/2023-10/2024-08-26_05-30-00.yaml
# File not found: D:/data/2023-10/2024-08-27_05-30-00.yaml
# File not found: D:/data/2023-10/2024-08-28_05-30-00.yaml
# File not found: D:/data/2023-10/2024-08-29_05-30-00.yaml
# File not found: D:/data/2023-10/2024-08-30_05-30-00.yaml
# File not found: D:/data/2023-10/2024-08-31_05-30-00.yaml
# File not found: D:/data/2023-10/2024-09-01_05-30-00.yaml
# File not found: D:/data/2023-10/2024-09-02_05-30-00.yaml
# File not found: D:/data/2023-10/2024-09-03_05-30-00.yaml
# File not found: D:/data/2023-10/2024-09-04_05-30-00.yaml
# File not found: D:/data/2023-10/2024-09-05_05-30-00.yaml
# File not found: D:/data/2023-10/2024-09-06_05-30-00.yaml
# File not found: D:/data/2023-10/2024-09-07_05-30-00.yaml
# File not found: D:/data/2023-10/2024-09-08_05-30-00.yaml
# File not found: D:/data/2023-10/2024-09-09_05-30-00.yaml
# File not found: D:/data/2023-10/2024-09-10_05-30-00.yaml
# File not found: D:/data/2023-10/2024-09-11_05-30-00.yaml
# File not found: D:/data/2023-10/2024-09-12_05-30-00.yaml
# File not found: D:/data/2023-10/2024-09-13_05-30-00.yaml
# File not found: D:/data/2023-10/2024-09-14_05-30-00.yaml
# File not found: D:/data/2023-10/2024-09-15_05-30-00.yaml
# File not found: D:/data/2023-10/2024-09-16_05-30-00.yaml
# File not found: D:/data/2023-10/2024-09-17_05-30-00.yaml
# File not found: D:/data/2023-10/2024-09-18_05-30-00.yaml
# File not found: D:/data/2023-10/2024-09-19_05-30-00.yaml
# File not found: D:/data/2023-10/2024-09-20_05-30-00.yaml
# File not found: D:/data/2023-10/2024-09-21_05-30-00.yaml
# File not found: D:/data/2023-10/2024-09-22_05-30-00.yaml
# File not found: D:/data/2023-10/2024-09-23_05-30-00.yaml
# File not found: D:/data/2023-10/2024-09-24_05-30-00.yaml
# File not found: D:/data/2023-10/2024-09-25_05-30-00.yaml
# File not found: D:/data/2023-10/2024-09-26_05-30-00.yaml
# File not found: D:/data/2023-10/2024-09-27_05-30-00.yaml
# File not found: D:/data/2023-10/2024-09-28_05-30-00.yaml
# File not found: D:/data/2023-10/2024-09-29_05-30-00.yaml
# File not found: D:/data/2023-10/2024-09-30_05-30-00.yaml
# File not found: D:/data/2023-10/2024-10-01_05-30-00.yaml
# File not found: D:/data/2023-10/2024-10-02_05-30-00.yaml
# File not found: D:/data/2023-10/2024-10-03_05-30-00.yaml
# File not found: D:/data/2023-10/2024-10-04_05-30-00.yaml
# File not found: D:/data/2023-10/2024-10-05_05-30-00.yaml
# File not found: D:/data/2023-10/2024-10-06_05-30-00.yaml
# File not found: D:/data/2023-10/2024-10-07_05-30-00.yaml
# File not found: D:/data/2023-10/2024-10-08_05-30-00.yaml
# File not found: D:/data/2023-10/2024-10-09_05-30-00.yaml
# File not found: D:/data/2023-10/2024-10-10_05-30-00.yaml
# File not found: D:/data/2023-10/2024-10-11_05-30-00.yaml
# File not found: D:/data/2023-10/2024-10-12_05-30-00.yaml
# File not found: D:/data/2023-10/2024-10-13_05-30-00.yaml
# File not found: D:/data/2023-10/2024-10-14_05-30-00.yaml
# File not found: D:/data/2023-10/2024-10-15_05-30-00.yaml
# File not found: D:/data/2023-10/2024-10-16_05-30-00.yaml
# File not found: D:/data/2023-10/2024-10-17_05-30-00.yaml
# File not found: D:/data/2023-10/2024-10-18_05-30-00.yaml
# File not found: D:/data/2023-10/2024-10-19_05-30-00.yaml
# File not found: D:/data/2023-10/2024-10-20_05-30-00.yaml
# File not found: D:/data/2023-10/2024-10-21_05-30-00.yaml
# File not found: D:/data/2023-10/2024-10-22_05-30-00.yaml
# File not found: D:/data/2023-10/2024-10-23_05-30-00.yaml
# File not found: D:/data/2023-10/2024-10-24_05-30-00.yaml
# File not found: D:/data/2023-10/2024-10-25_05-30-00.yaml
# File not found: D:/data/2023-10/2024-10-26_05-30-00.yaml
# File not found: D:/data/2023-10/2024-10-27_05-30-00.yaml
# File not found: D:/data/2023-10/2024-10-28_05-30-00.yaml
# File not found: D:/data/2023-10/2024-10-29_05-30-00.yaml
# File not found: D:/data/2023-10/2024-10-30_05-30-00.yaml
# File not found: D:/data/2023-10/2024-10-31_05-30-00.yaml
# File not found: D:/data/2023-10/2024-11-01_05-30-00.yaml
# File not found: D:/data/2023-10/2024-11-02_05-30-00.yaml
# File not found: D:/data/2023-10/2024-11-03_05-30-00.yaml
# File not found: D:/data/2023-10/2024-11-04_05-30-00.yaml
# File not found: D:/data/2023-10/2024-11-05_05-30-00.yaml
# File not found: D:/data/2023-10/2024-11-06_05-30-00.yaml
# File not found: D:/data/2023-10/2024-11-07_05-30-00.yaml
# File not found: D:/data/2023-10/2024-11-08_05-30-00.yaml
# File not found: D:/data/2023-10/2024-11-09_05-30-00.yaml
# File not found: D:/data/2023-10/2024-11-10_05-30-00.yaml
# File not found: D:/data/2023-10/2024-11-11_05-30-00.yaml
# File not found: D:/data/2023-10/2024-11-12_05-30-00.yaml
# File not found: D:/data/2023-10/2024-11-13_05-30-00.yaml
# File not found: D:/data/2023-10/2024-11-14_05-30-00.yaml
# File not found: D:/data/2023-10/2024-11-15_05-30-00.yaml
# File not found: D:/data/2023-10/2024-11-16_05-30-00.yaml
# File not found: D:/data/2023-10/2024-11-17_05-30-00.yaml
# File not found: D:/data/2023-10/2024-11-18_05-30-00.yaml
# File not found: D:/data/2023-10/2024-11-19_05-30-00.yaml
# File not found: D:/data/2023-10/2024-11-20_05-30-00.yaml
# File not found: D:/data/2023-10/2024-11-21_05-30-00.yaml
# File not found: D:/data/2023-10/2024-11-22_05-30-00.yaml
# File not found: D:/data/2023-11/2023-10-03_05-30-00.yaml
# File not found: D:/data/2023-11/2023-10-04_05-30-00.yaml
# File not found: D:/data/2023-11/2023-10-05_05-30-00.yaml
# File not found: D:/data/2023-11/2023-10-06_05-30-00.yaml
# File not found: D:/data/2023-11/2023-10-07_05-30-00.yaml
# File not found: D:/data/2023-11/2023-10-08_05-30-00.yaml
# File not found: D:/data/2023-11/2023-10-09_05-30-00.yaml
# File not found: D:/data/2023-11/2023-10-10_05-30-00.yaml
# File not found: D:/data/2023-11/2023-10-11_05-30-00.yaml
# File not found: D:/data/2023-11/2023-10-12_05-30-00.yaml
# File not found: D:/data/2023-11/2023-10-13_05-30-00.yaml
# File not found: D:/data/2023-11/2023-10-14_05-30-00.yaml
# File not found: D:/data/2023-11/2023-10-15_05-30-00.yaml
# File not found: D:/data/2023-11/2023-10-16_05-30-00.yaml
# File not found: D:/data/2023-11/2023-10-17_05-30-00.yaml
# File not found: D:/data/2023-11/2023-10-18_05-30-00.yaml
# File not found: D:/data/2023-11/2023-10-19_05-30-00.yaml
# File not found: D:/data/2023-11/2023-10-20_05-30-00.yaml
# File not found: D:/data/2023-11/2023-10-21_05-30-00.yaml
# File not found: D:/data/2023-11/2023-10-22_05-30-00.yaml
# File not found: D:/data/2023-11/2023-10-23_05-30-00.yaml
# File not found: D:/data/2023-11/2023-10-24_05-30-00.yaml
# File not found: D:/data/2023-11/2023-10-25_05-30-00.yaml
# File not found: D:/data/2023-11/2023-10-26_05-30-00.yaml
# File not found: D:/data/2023-11/2023-10-27_05-30-00.yaml
# File not found: D:/data/2023-11/2023-10-28_05-30-00.yaml
# File not found: D:/data/2023-11/2023-10-29_05-30-00.yaml
# File not found: D:/data/2023-11/2023-10-30_05-30-00.yaml
# File not found: D:/data/2023-11/2023-10-31_05-30-00.yaml
# File not found: D:/data/2023-11/2023-11-04_05-30-00.yaml
# File not found: D:/data/2023-11/2023-11-05_05-30-00.yaml
# File not found: D:/data/2023-11/2023-11-11_05-30-00.yaml
# File not found: D:/data/2023-11/2023-11-14_05-30-00.yaml
# File not found: D:/data/2023-11/2023-11-18_05-30-00.yaml
# File not found: D:/data/2023-11/2023-11-19_05-30-00.yaml
# File not found: D:/data/2023-11/2023-11-25_05-30-00.yaml
# File not found: D:/data/2023-11/2023-11-26_05-30-00.yaml
# File not found: D:/data/2023-11/2023-11-27_05-30-00.yaml
# File not found: D:/data/2023-11/2023-12-01_05-30-00.yaml
# File not found: D:/data/2023-11/2023-12-02_05-30-00.yaml
# File not found: D:/data/2023-11/2023-12-03_05-30-00.yaml
# File not found: D:/data/2023-11/2023-12-04_05-30-00.yaml
# File not found: D:/data/2023-11/2023-12-05_05-30-00.yaml
# File not found: D:/data/2023-11/2023-12-06_05-30-00.yaml
# File not found: D:/data/2023-11/2023-12-07_05-30-00.yaml
# File not found: D:/data/2023-11/2023-12-08_05-30-00.yaml
# File not found: D:/data/2023-11/2023-12-09_05-30-00.yaml
# File not found: D:/data/2023-11/2023-12-10_05-30-00.yaml
# File not found: D:/data/2023-11/2023-12-11_05-30-00.yaml
# File not found: D:/data/2023-11/2023-12-12_05-30-00.yaml
# File not found: D:/data/2023-11/2023-12-13_05-30-00.yaml
# File not found: D:/data/2023-11/2023-12-14_05-30-00.yaml
# File not found: D:/data/2023-11/2023-12-15_05-30-00.yaml
# File not found: D:/data/2023-11/2023-12-16_05-30-00.yaml
# File not found: D:/data/2023-11/2023-12-17_05-30-00.yaml
# File not found: D:/data/2023-11/2023-12-18_05-30-00.yaml
# File not found: D:/data/2023-11/2023-12-19_05-30-00.yaml
# File not found: D:/data/2023-11/2023-12-20_05-30-00.yaml
# File not found: D:/data/2023-11/2023-12-21_05-30-00.yaml
# File not found: D:/data/2023-11/2023-12-22_05-30-00.yaml
# File not found: D:/data/2023-11/2023-12-23_05-30-00.yaml
# File not found: D:/data/2023-11/2023-12-24_05-30-00.yaml
# File not found: D:/data/2023-11/2023-12-25_05-30-00.yaml
# File not found: D:/data/2023-11/2023-12-26_05-30-00.yaml
# File not found: D:/data/2023-11/2023-12-27_05-30-00.yaml
# File not found: D:/data/2023-11/2023-12-28_05-30-00.yaml
# File not found: D:/data/2023-11/2023-12-29_05-30-00.yaml
# File not found: D:/data/2023-11/2023-12-30_05-30-00.yaml
# File not found: D:/data/2023-11/2023-12-31_05-30-00.yaml
# File not found: D:/data/2023-11/2024-01-01_05-30-00.yaml
# File not found: D:/data/2023-11/2024-01-02_05-30-00.yaml
# File not found: D:/data/2023-11/2024-01-03_05-30-00.yaml
# File not found: D:/data/2023-11/2024-01-04_05-30-00.yaml
# File not found: D:/data/2023-11/2024-01-05_05-30-00.yaml
# File not found: D:/data/2023-11/2024-01-06_05-30-00.yaml
# File not found: D:/data/2023-11/2024-01-07_05-30-00.yaml
# File not found: D:/data/2023-11/2024-01-08_05-30-00.yaml
# File not found: D:/data/2023-11/2024-01-09_05-30-00.yaml
# File not found: D:/data/2023-11/2024-01-10_05-30-00.yaml
# File not found: D:/data/2023-11/2024-01-11_05-30-00.yaml
# File not found: D:/data/2023-11/2024-01-12_05-30-00.yaml
# File not found: D:/data/2023-11/2024-01-13_05-30-00.yaml
# File not found: D:/data/2023-11/2024-01-14_05-30-00.yaml
# File not found: D:/data/2023-11/2024-01-15_05-30-00.yaml
# File not found: D:/data/2023-11/2024-01-16_05-30-00.yaml
# File not found: D:/data/2023-11/2024-01-17_05-30-00.yaml
# File not found: D:/data/2023-11/2024-01-18_05-30-00.yaml
# File not found: D:/data/2023-11/2024-01-19_05-30-00.yaml
# File not found: D:/data/2023-11/2024-01-20_05-30-00.yaml
# File not found: D:/data/2023-11/2024-01-21_05-30-00.yaml
# File not found: D:/data/2023-11/2024-01-22_05-30-00.yaml
# File not found: D:/data/2023-11/2024-01-23_05-30-00.yaml
# File not found: D:/data/2023-11/2024-01-24_05-30-00.yaml
# File not found: D:/data/2023-11/2024-01-25_05-30-00.yaml
# File not found: D:/data/2023-11/2024-01-26_05-30-00.yaml
# File not found: D:/data/2023-11/2024-01-27_05-30-00.yaml
# File not found: D:/data/2023-11/2024-01-28_05-30-00.yaml
# File not found: D:/data/2023-11/2024-01-29_05-30-00.yaml
# File not found: D:/data/2023-11/2024-01-30_05-30-00.yaml
# File not found: D:/data/2023-11/2024-01-31_05-30-00.yaml
# File not found: D:/data/2023-11/2024-02-01_05-30-00.yaml
# File not found: D:/data/2023-11/2024-02-02_05-30-00.yaml
# File not found: D:/data/2023-11/2024-02-03_05-30-00.yaml
# File not found: D:/data/2023-11/2024-02-04_05-30-00.yaml
# File not found: D:/data/2023-11/2024-02-05_05-30-00.yaml
# File not found: D:/data/2023-11/2024-02-06_05-30-00.yaml
# File not found: D:/data/2023-11/2024-02-07_05-30-00.yaml
# File not found: D:/data/2023-11/2024-02-08_05-30-00.yaml
# File not found: D:/data/2023-11/2024-02-09_05-30-00.yaml
# File not found: D:/data/2023-11/2024-02-10_05-30-00.yaml
# File not found: D:/data/2023-11/2024-02-11_05-30-00.yaml
# File not found: D:/data/2023-11/2024-02-12_05-30-00.yaml
# File not found: D:/data/2023-11/2024-02-13_05-30-00.yaml
# File not found: D:/data/2023-11/2024-02-14_05-30-00.yaml
# File not found: D:/data/2023-11/2024-02-15_05-30-00.yaml
# File not found: D:/data/2023-11/2024-02-16_05-30-00.yaml
# File not found: D:/data/2023-11/2024-02-17_05-30-00.yaml
# File not found: D:/data/2023-11/2024-02-18_05-30-00.yaml
# File not found: D:/data/2023-11/2024-02-19_05-30-00.yaml
# File not found: D:/data/2023-11/2024-02-20_05-30-00.yaml
# File not found: D:/data/2023-11/2024-02-21_05-30-00.yaml
# File not found: D:/data/2023-11/2024-02-22_05-30-00.yaml
# File not found: D:/data/2023-11/2024-02-23_05-30-00.yaml
# File not found: D:/data/2023-11/2024-02-24_05-30-00.yaml
# File not found: D:/data/2023-11/2024-02-25_05-30-00.yaml
# File not found: D:/data/2023-11/2024-02-26_05-30-00.yaml
# File not found: D:/data/2023-11/2024-02-27_05-30-00.yaml
# File not found: D:/data/2023-11/2024-02-28_05-30-00.yaml
# File not found: D:/data/2023-11/2024-02-29_05-30-00.yaml
# File not found: D:/data/2023-11/2024-03-01_05-30-00.yaml
# File not found: D:/data/2023-11/2024-03-02_05-30-00.yaml
# File not found: D:/data/2023-11/2024-03-03_05-30-00.yaml
# File not found: D:/data/2023-11/2024-03-04_05-30-00.yaml
# File not found: D:/data/2023-11/2024-03-05_05-30-00.yaml
# File not found: D:/data/2023-11/2024-03-06_05-30-00.yaml
# File not found: D:/data/2023-11/2024-03-07_05-30-00.yaml
# File not found: D:/data/2023-11/2024-03-08_05-30-00.yaml
# File not found: D:/data/2023-11/2024-03-09_05-30-00.yaml
# File not found: D:/data/2023-11/2024-03-10_05-30-00.yaml
# File not found: D:/data/2023-11/2024-03-11_05-30-00.yaml
# File not found: D:/data/2023-11/2024-03-12_05-30-00.yaml
# File not found: D:/data/2023-11/2024-03-13_05-30-00.yaml
# File not found: D:/data/2023-11/2024-03-14_05-30-00.yaml
# File not found: D:/data/2023-11/2024-03-15_05-30-00.yaml
# File not found: D:/data/2023-11/2024-03-16_05-30-00.yaml
# File not found: D:/data/2023-11/2024-03-17_05-30-00.yaml
# File not found: D:/data/2023-11/2024-03-18_05-30-00.yaml
# File not found: D:/data/2023-11/2024-03-19_05-30-00.yaml
# File not found: D:/data/2023-11/2024-03-20_05-30-00.yaml
# File not found: D:/data/2023-11/2024-03-21_05-30-00.yaml
# File not found: D:/data/2023-11/2024-03-22_05-30-00.yaml
# File not found: D:/data/2023-11/2024-03-23_05-30-00.yaml
# File not found: D:/data/2023-11/2024-03-24_05-30-00.yaml
# File not found: D:/data/2023-11/2024-03-25_05-30-00.yaml
# File not found: D:/data/2023-11/2024-03-26_05-30-00.yaml
# File not found: D:/data/2023-11/2024-03-27_05-30-00.yaml
# File not found: D:/data/2023-11/2024-03-28_05-30-00.yaml
# File not found: D:/data/2023-11/2024-03-29_05-30-00.yaml
# File not found: D:/data/2023-11/2024-03-30_05-30-00.yaml
# File not found: D:/data/2023-11/2024-03-31_05-30-00.yaml
# File not found: D:/data/2023-11/2024-04-01_05-30-00.yaml
# File not found: D:/data/2023-11/2024-04-02_05-30-00.yaml
# File not found: D:/data/2023-11/2024-04-03_05-30-00.yaml
# File not found: D:/data/2023-11/2024-04-04_05-30-00.yaml
# File not found: D:/data/2023-11/2024-04-05_05-30-00.yaml
# File not found: D:/data/2023-11/2024-04-06_05-30-00.yaml
# File not found: D:/data/2023-11/2024-04-07_05-30-00.yaml
# File not found: D:/data/2023-11/2024-04-08_05-30-00.yaml
# File not found: D:/data/2023-11/2024-04-09_05-30-00.yaml
# File not found: D:/data/2023-11/2024-04-10_05-30-00.yaml
# File not found: D:/data/2023-11/2024-04-11_05-30-00.yaml
# File not found: D:/data/2023-11/2024-04-12_05-30-00.yaml
# File not found: D:/data/2023-11/2024-04-13_05-30-00.yaml
# File not found: D:/data/2023-11/2024-04-14_05-30-00.yaml
# File not found: D:/data/2023-11/2024-04-15_05-30-00.yaml
# File not found: D:/data/2023-11/2024-04-16_05-30-00.yaml
# File not found: D:/data/2023-11/2024-04-17_05-30-00.yaml
# File not found: D:/data/2023-11/2024-04-18_05-30-00.yaml
# File not found: D:/data/2023-11/2024-04-19_05-30-00.yaml
# File not found: D:/data/2023-11/2024-04-20_05-30-00.yaml
# File not found: D:/data/2023-11/2024-04-21_05-30-00.yaml
# File not found: D:/data/2023-11/2024-04-22_05-30-00.yaml
# File not found: D:/data/2023-11/2024-04-23_05-30-00.yaml
# File not found: D:/data/2023-11/2024-04-24_05-30-00.yaml
# File not found: D:/data/2023-11/2024-04-25_05-30-00.yaml
# File not found: D:/data/2023-11/2024-04-26_05-30-00.yaml
# File not found: D:/data/2023-11/2024-04-27_05-30-00.yaml
# File not found: D:/data/2023-11/2024-04-28_05-30-00.yaml
# File not found: D:/data/2023-11/2024-04-29_05-30-00.yaml
# File not found: D:/data/2023-11/2024-04-30_05-30-00.yaml
# File not found: D:/data/2023-11/2024-05-01_05-30-00.yaml
# File not found: D:/data/2023-11/2024-05-02_05-30-00.yaml
# File not found: D:/data/2023-11/2024-05-03_05-30-00.yaml
# File not found: D:/data/2023-11/2024-05-04_05-30-00.yaml
# File not found: D:/data/2023-11/2024-05-05_05-30-00.yaml
# File not found: D:/data/2023-11/2024-05-06_05-30-00.yaml
# File not found: D:/data/2023-11/2024-05-07_05-30-00.yaml
# File not found: D:/data/2023-11/2024-05-08_05-30-00.yaml
# File not found: D:/data/2023-11/2024-05-09_05-30-00.yaml
# File not found: D:/data/2023-11/2024-05-10_05-30-00.yaml
# File not found: D:/data/2023-11/2024-05-11_05-30-00.yaml
# File not found: D:/data/2023-11/2024-05-12_05-30-00.yaml
# File not found: D:/data/2023-11/2024-05-13_05-30-00.yaml
# File not found: D:/data/2023-11/2024-05-14_05-30-00.yaml
# File not found: D:/data/2023-11/2024-05-15_05-30-00.yaml
# File not found: D:/data/2023-11/2024-05-16_05-30-00.yaml
# File not found: D:/data/2023-11/2024-05-17_05-30-00.yaml
# File not found: D:/data/2023-11/2024-05-18_05-30-00.yaml
# File not found: D:/data/2023-11/2024-05-19_05-30-00.yaml
# File not found: D:/data/2023-11/2024-05-20_05-30-00.yaml
# File not found: D:/data/2023-11/2024-05-21_05-30-00.yaml
# File not found: D:/data/2023-11/2024-05-22_05-30-00.yaml
# File not found: D:/data/2023-11/2024-05-23_05-30-00.yaml
# File not found: D:/data/2023-11/2024-05-24_05-30-00.yaml
# File not found: D:/data/2023-11/2024-05-25_05-30-00.yaml
# File not found: D:/data/2023-11/2024-05-26_05-30-00.yaml
# File not found: D:/data/2023-11/2024-05-27_05-30-00.yaml
# File not found: D:/data/2023-11/2024-05-28_05-30-00.yaml
# File not found: D:/data/2023-11/2024-05-29_05-30-00.yaml
# File not found: D:/data/2023-11/2024-05-30_05-30-00.yaml
# File not found: D:/data/2023-11/2024-05-31_05-30-00.yaml
# File not found: D:/data/2023-11/2024-06-01_05-30-00.yaml
# File not found: D:/data/2023-11/2024-06-02_05-30-00.yaml
# File not found: D:/data/2023-11/2024-06-03_05-30-00.yaml
# File not found: D:/data/2023-11/2024-06-04_05-30-00.yaml
# File not found: D:/data/2023-11/2024-06-05_05-30-00.yaml
# File not found: D:/data/2023-11/2024-06-06_05-30-00.yaml
# File not found: D:/data/2023-11/2024-06-07_05-30-00.yaml
# File not found: D:/data/2023-11/2024-06-08_05-30-00.yaml
# File not found: D:/data/2023-11/2024-06-09_05-30-00.yaml
# File not found: D:/data/2023-11/2024-06-10_05-30-00.yaml
# File not found: D:/data/2023-11/2024-06-11_05-30-00.yaml
# File not found: D:/data/2023-11/2024-06-12_05-30-00.yaml
# File not found: D:/data/2023-11/2024-06-13_05-30-00.yaml
# File not found: D:/data/2023-11/2024-06-14_05-30-00.yaml
# File not found: D:/data/2023-11/2024-06-15_05-30-00.yaml
# File not found: D:/data/2023-11/2024-06-16_05-30-00.yaml
# File not found: D:/data/2023-11/2024-06-17_05-30-00.yaml
# File not found: D:/data/2023-11/2024-06-18_05-30-00.yaml
# File not found: D:/data/2023-11/2024-06-19_05-30-00.yaml
# File not found: D:/data/2023-11/2024-06-20_05-30-00.yaml
# File not found: D:/data/2023-11/2024-06-21_05-30-00.yaml
# File not found: D:/data/2023-11/2024-06-22_05-30-00.yaml
# File not found: D:/data/2023-11/2024-06-23_05-30-00.yaml
# File not found: D:/data/2023-11/2024-06-24_05-30-00.yaml
# File not found: D:/data/2023-11/2024-06-25_05-30-00.yaml
# File not found: D:/data/2023-11/2024-06-26_05-30-00.yaml
# File not found: D:/data/2023-11/2024-06-27_05-30-00.yaml
# File not found: D:/data/2023-11/2024-06-28_05-30-00.yaml
# File not found: D:/data/2023-11/2024-06-29_05-30-00.yaml
# File not found: D:/data/2023-11/2024-06-30_05-30-00.yaml
# File not found: D:/data/2023-11/2024-07-01_05-30-00.yaml
# File not found: D:/data/2023-11/2024-07-02_05-30-00.yaml
# File not found: D:/data/2023-11/2024-07-03_05-30-00.yaml
# File not found: D:/data/2023-11/2024-07-04_05-30-00.yaml
# File not found: D:/data/2023-11/2024-07-05_05-30-00.yaml
# File not found: D:/data/2023-11/2024-07-06_05-30-00.yaml
# File not found: D:/data/2023-11/2024-07-07_05-30-00.yaml
# File not found: D:/data/2023-11/2024-07-08_05-30-00.yaml
# File not found: D:/data/2023-11/2024-07-09_05-30-00.yaml
# File not found: D:/data/2023-11/2024-07-10_05-30-00.yaml
# File not found: D:/data/2023-11/2024-07-11_05-30-00.yaml
# File not found: D:/data/2023-11/2024-07-12_05-30-00.yaml
# File not found: D:/data/2023-11/2024-07-13_05-30-00.yaml
# File not found: D:/data/2023-11/2024-07-14_05-30-00.yaml
# File not found: D:/data/2023-11/2024-07-15_05-30-00.yaml
# File not found: D:/data/2023-11/2024-07-16_05-30-00.yaml
# File not found: D:/data/2023-11/2024-07-17_05-30-00.yaml
# File not found: D:/data/2023-11/2024-07-18_05-30-00.yaml
# File not found: D:/data/2023-11/2024-07-19_05-30-00.yaml
# File not found: D:/data/2023-11/2024-07-20_05-30-00.yaml
# File not found: D:/data/2023-11/2024-07-21_05-30-00.yaml
# File not found: D:/data/2023-11/2024-07-22_05-30-00.yaml
# File not found: D:/data/2023-11/2024-07-23_05-30-00.yaml
# File not found: D:/data/2023-11/2024-07-24_05-30-00.yaml
# File not found: D:/data/2023-11/2024-07-25_05-30-00.yaml
# File not found: D:/data/2023-11/2024-07-26_05-30-00.yaml
# File not found: D:/data/2023-11/2024-07-27_05-30-00.yaml
# File not found: D:/data/2023-11/2024-07-28_05-30-00.yaml
# File not found: D:/data/2023-11/2024-07-29_05-30-00.yaml
# File not found: D:/data/2023-11/2024-07-30_05-30-00.yaml
# File not found: D:/data/2023-11/2024-07-31_05-30-00.yaml
# File not found: D:/data/2023-11/2024-08-01_05-30-00.yaml
# File not found: D:/data/2023-11/2024-08-02_05-30-00.yaml
# File not found: D:/data/2023-11/2024-08-03_05-30-00.yaml
# File not found: D:/data/2023-11/2024-08-04_05-30-00.yaml
# File not found: D:/data/2023-11/2024-08-05_05-30-00.yaml
# File not found: D:/data/2023-11/2024-08-06_05-30-00.yaml
# File not found: D:/data/2023-11/2024-08-07_05-30-00.yaml
# File not found: D:/data/2023-11/2024-08-08_05-30-00.yaml
# File not found: D:/data/2023-11/2024-08-09_05-30-00.yaml
# File not found: D:/data/2023-11/2024-08-10_05-30-00.yaml
# File not found: D:/data/2023-11/2024-08-11_05-30-00.yaml
# File not found: D:/data/2023-11/2024-08-12_05-30-00.yaml
# File not found: D:/data/2023-11/2024-08-13_05-30-00.yaml
# File not found: D:/data/2023-11/2024-08-14_05-30-00.yaml
# File not found: D:/data/2023-11/2024-08-15_05-30-00.yaml
# File not found: D:/data/2023-11/2024-08-16_05-30-00.yaml
# File not found: D:/data/2023-11/2024-08-17_05-30-00.yaml
# File not found: D:/data/2023-11/2024-08-18_05-30-00.yaml
# File not found: D:/data/2023-11/2024-08-19_05-30-00.yaml
# File not found: D:/data/2023-11/2024-08-20_05-30-00.yaml
# File not found: D:/data/2023-11/2024-08-21_05-30-00.yaml
# File not found: D:/data/2023-11/2024-08-22_05-30-00.yaml
# File not found: D:/data/2023-11/2024-08-23_05-30-00.yaml
# File not found: D:/data/2023-11/2024-08-24_05-30-00.yaml
# File not found: D:/data/2023-11/2024-08-25_05-30-00.yaml
# File not found: D:/data/2023-11/2024-08-26_05-30-00.yaml
# File not found: D:/data/2023-11/2024-08-27_05-30-00.yaml
# File not found: D:/data/2023-11/2024-08-28_05-30-00.yaml
# File not found: D:/data/2023-11/2024-08-29_05-30-00.yaml
# File not found: D:/data/2023-11/2024-08-30_05-30-00.yaml
# File not found: D:/data/2023-11/2024-08-31_05-30-00.yaml
# File not found: D:/data/2023-11/2024-09-01_05-30-00.yaml
# File not found: D:/data/2023-11/2024-09-02_05-30-00.yaml
# File not found: D:/data/2023-11/2024-09-03_05-30-00.yaml
# File not found: D:/data/2023-11/2024-09-04_05-30-00.yaml
# File not found: D:/data/2023-11/2024-09-05_05-30-00.yaml
# File not found: D:/data/2023-11/2024-09-06_05-30-00.yaml
# File not found: D:/data/2023-11/2024-09-07_05-30-00.yaml
# File not found: D:/data/2023-11/2024-09-08_05-30-00.yaml
# File not found: D:/data/2023-11/2024-09-09_05-30-00.yaml
# File not found: D:/data/2023-11/2024-09-10_05-30-00.yaml
# File not found: D:/data/2023-11/2024-09-11_05-30-00.yaml
# File not found: D:/data/2023-11/2024-09-12_05-30-00.yaml
# File not found: D:/data/2023-11/2024-09-13_05-30-00.yaml
# File not found: D:/data/2023-11/2024-09-14_05-30-00.yaml
# File not found: D:/data/2023-11/2024-09-15_05-30-00.yaml
# File not found: D:/data/2023-11/2024-09-16_05-30-00.yaml
# File not found: D:/data/2023-11/2024-09-17_05-30-00.yaml
# File not found: D:/data/2023-11/2024-09-18_05-30-00.yaml
# File not found: D:/data/2023-11/2024-09-19_05-30-00.yaml
# File not found: D:/data/2023-11/2024-09-20_05-30-00.yaml
# File not found: D:/data/2023-11/2024-09-21_05-30-00.yaml
# File not found: D:/data/2023-11/2024-09-22_05-30-00.yaml
# File not found: D:/data/2023-11/2024-09-23_05-30-00.yaml
# File not found: D:/data/2023-11/2024-09-24_05-30-00.yaml
# File not found: D:/data/2023-11/2024-09-25_05-30-00.yaml
# File not found: D:/data/2023-11/2024-09-26_05-30-00.yaml
# File not found: D:/data/2023-11/2024-09-27_05-30-00.yaml
# File not found: D:/data/2023-11/2024-09-28_05-30-00.yaml
# File not found: D:/data/2023-11/2024-09-29_05-30-00.yaml
# File not found: D:/data/2023-11/2024-09-30_05-30-00.yaml
# File not found: D:/data/2023-11/2024-10-01_05-30-00.yaml
# File not found: D:/data/2023-11/2024-10-02_05-30-00.yaml
# File not found: D:/data/2023-11/2024-10-03_05-30-00.yaml
# File not found: D:/data/2023-11/2024-10-04_05-30-00.yaml
# File not found: D:/data/2023-11/2024-10-05_05-30-00.yaml
# File not found: D:/data/2023-11/2024-10-06_05-30-00.yaml
# File not found: D:/data/2023-11/2024-10-07_05-30-00.yaml
# File not found: D:/data/2023-11/2024-10-08_05-30-00.yaml
# File not found: D:/data/2023-11/2024-10-09_05-30-00.yaml
# File not found: D:/data/2023-11/2024-10-10_05-30-00.yaml
# File not found: D:/data/2023-11/2024-10-11_05-30-00.yaml
# File not found: D:/data/2023-11/2024-10-12_05-30-00.yaml
# File not found: D:/data/2023-11/2024-10-13_05-30-00.yaml
# File not found: D:/data/2023-11/2024-10-14_05-30-00.yaml
# File not found: D:/data/2023-11/2024-10-15_05-30-00.yaml
# File not found: D:/data/2023-11/2024-10-16_05-30-00.yaml
# File not found: D:/data/2023-11/2024-10-17_05-30-00.yaml
# File not found: D:/data/2023-11/2024-10-18_05-30-00.yaml
# File not found: D:/data/2023-11/2024-10-19_05-30-00.yaml
# File not found: D:/data/2023-11/2024-10-20_05-30-00.yaml
# File not found: D:/data/2023-11/2024-10-21_05-30-00.yaml
# File not found: D:/data/2023-11/2024-10-22_05-30-00.yaml
# File not found: D:/data/2023-11/2024-10-23_05-30-00.yaml
# File not found: D:/data/2023-11/2024-10-24_05-30-00.yaml
# File not found: D:/data/2023-11/2024-10-25_05-30-00.yaml
# File not found: D:/data/2023-11/2024-10-26_05-30-00.yaml
# File not found: D:/data/2023-11/2024-10-27_05-30-00.yaml
# File not found: D:/data/2023-11/2024-10-28_05-30-00.yaml
# File not found: D:/data/2023-11/2024-10-29_05-30-00.yaml
# File not found: D:/data/2023-11/2024-10-30_05-30-00.yaml
# File not found: D:/data/2023-11/2024-10-31_05-30-00.yaml
# File not found: D:/data/2023-11/2024-11-01_05-30-00.yaml
# File not found: D:/data/2023-11/2024-11-02_05-30-00.yaml
# File not found: D:/data/2023-11/2024-11-03_05-30-00.yaml
# File not found: D:/data/2023-11/2024-11-04_05-30-00.yaml
# File not found: D:/data/2023-11/2024-11-05_05-30-00.yaml
# File not found: D:/data/2023-11/2024-11-06_05-30-00.yaml
# File not found: D:/data/2023-11/2024-11-07_05-30-00.yaml
# File not found: D:/data/2023-11/2024-11-08_05-30-00.yaml
# File not found: D:/data/2023-11/2024-11-09_05-30-00.yaml
# File not found: D:/data/2023-11/2024-11-10_05-30-00.yaml
# File not found: D:/data/2023-11/2024-11-11_05-30-00.yaml
# File not found: D:/data/2023-11/2024-11-12_05-30-00.yaml
# File not found: D:/data/2023-11/2024-11-13_05-30-00.yaml
# File not found: D:/data/2023-11/2024-11-14_05-30-00.yaml
# File not found: D:/data/2023-11/2024-11-15_05-30-00.yaml
# File not found: D:/data/2023-11/2024-11-16_05-30-00.yaml
# File not found: D:/data/2023-11/2024-11-17_05-30-00.yaml
# File not found: D:/data/2023-11/2024-11-18_05-30-00.yaml
# File not found: D:/data/2023-11/2024-11-19_05-30-00.yaml
# File not found: D:/data/2023-11/2024-11-20_05-30-00.yaml
# File not found: D:/data/2023-11/2024-11-21_05-30-00.yaml
# File not found: D:/data/2023-11/2024-11-22_05-30-00.yaml
# File not found: D:/data/2023-12/2023-10-03_05-30-00.yaml
# File not found: D:/data/2023-12/2023-10-04_05-30-00.yaml
# File not found: D:/data/2023-12/2023-10-05_05-30-00.yaml
# File not found: D:/data/2023-12/2023-10-06_05-30-00.yaml
# File not found: D:/data/2023-12/2023-10-07_05-30-00.yaml
# File not found: D:/data/2023-12/2023-10-08_05-30-00.yaml
# File not found: D:/data/2023-12/2023-10-09_05-30-00.yaml
# File not found: D:/data/2023-12/2023-10-10_05-30-00.yaml
# File not found: D:/data/2023-12/2023-10-11_05-30-00.yaml
# File not found: D:/data/2023-12/2023-10-12_05-30-00.yaml
# File not found: D:/data/2023-12/2023-10-13_05-30-00.yaml
# File not found: D:/data/2023-12/2023-10-14_05-30-00.yaml
# File not found: D:/data/2023-12/2023-10-15_05-30-00.yaml
# File not found: D:/data/2023-12/2023-10-16_05-30-00.yaml
# File not found: D:/data/2023-12/2023-10-17_05-30-00.yaml
# File not found: D:/data/2023-12/2023-10-18_05-30-00.yaml
# File not found: D:/data/2023-12/2023-10-19_05-30-00.yaml
# File not found: D:/data/2023-12/2023-10-20_05-30-00.yaml
# File not found: D:/data/2023-12/2023-10-21_05-30-00.yaml
# File not found: D:/data/2023-12/2023-10-22_05-30-00.yaml
# File not found: D:/data/2023-12/2023-10-23_05-30-00.yaml
# File not found: D:/data/2023-12/2023-10-24_05-30-00.yaml
# File not found: D:/data/2023-12/2023-10-25_05-30-00.yaml
# File not found: D:/data/2023-12/2023-10-26_05-30-00.yaml
# File not found: D:/data/2023-12/2023-10-27_05-30-00.yaml
# File not found: D:/data/2023-12/2023-10-28_05-30-00.yaml
# File not found: D:/data/2023-12/2023-10-29_05-30-00.yaml
# File not found: D:/data/2023-12/2023-10-30_05-30-00.yaml
# File not found: D:/data/2023-12/2023-10-31_05-30-00.yaml
# File not found: D:/data/2023-12/2023-11-01_05-30-00.yaml
# File not found: D:/data/2023-12/2023-11-02_05-30-00.yaml
# File not found: D:/data/2023-12/2023-11-03_05-30-00.yaml
# File not found: D:/data/2023-12/2023-11-04_05-30-00.yaml
# File not found: D:/data/2023-12/2023-11-05_05-30-00.yaml
# File not found: D:/data/2023-12/2023-11-06_05-30-00.yaml
# File not found: D:/data/2023-12/2023-11-07_05-30-00.yaml
# File not found: D:/data/2023-12/2023-11-08_05-30-00.yaml
# File not found: D:/data/2023-12/2023-11-09_05-30-00.yaml
# File not found: D:/data/2023-12/2023-11-10_05-30-00.yaml
# File not found: D:/data/2023-12/2023-11-11_05-30-00.yaml
# File not found: D:/data/2023-12/2023-11-12_05-30-00.yaml
# File not found: D:/data/2023-12/2023-11-13_05-30-00.yaml
# File not found: D:/data/2023-12/2023-11-14_05-30-00.yaml
# File not found: D:/data/2023-12/2023-11-15_05-30-00.yaml
# File not found: D:/data/2023-12/2023-11-16_05-30-00.yaml
# File not found: D:/data/2023-12/2023-11-17_05-30-00.yaml
# File not found: D:/data/2023-12/2023-11-18_05-30-00.yaml
# File not found: D:/data/2023-12/2023-11-19_05-30-00.yaml
# File not found: D:/data/2023-12/2023-11-20_05-30-00.yaml
# ...
# File not found: D:/data/2024-11/2024-02-13_05-30-00.yaml
# File not found: D:/data/2024-11/2024-02-14_05-30-00.yaml
# File not found: D:/data/2024-11/2024-02-15_05-30-00.yaml
# File not found: D:/data/2024-11/2024-02-16_05-30-00.yaml
# File not found: D:/data/2024-11/2024-02-17_05-30-00.yaml
# File not found: D:/data/2024-11/2024-02-18_05-30-00.yaml
# File not found: D:/data/2024-11/2024-02-19_05-30-00.yaml
# File not found: D:/data/2024-11/2024-02-20_05-30-00.yaml
# File not found: D:/data/2024-11/2024-02-21_05-30-00.yaml
# File not found: D:/data/2024-11/2024-02-22_05-30-00.yaml
# File not found: D:/data/2024-11/2024-02-23_05-30-00.yaml
# File not found: D:/data/2024-11/2024-02-24_05-30-00.yaml
# File not found: D:/data/2024-11/2024-02-25_05-30-00.yaml
# File not found: D:/data/2024-11/2024-02-26_05-30-00.yaml
# File not found: D:/data/2024-11/2024-02-27_05-30-00.yaml
# File not found: D:/data/2024-11/2024-02-28_05-30-00.yaml
# File not found: D:/data/2024-11/2024-02-29_05-30-00.yaml
# File not found: D:/data/2024-11/2024-03-01_05-30-00.yaml
# File not found: D:/data/2024-11/2024-03-02_05-30-00.yaml
# File not found: D:/data/2024-11/2024-03-03_05-30-00.yaml
# File not found: D:/data/2024-11/2024-03-04_05-30-00.yaml
# File not found: D:/data/2024-11/2024-03-05_05-30-00.yaml
# File not found: D:/data/2024-11/2024-03-06_05-30-00.yaml
# File not found: D:/data/2024-11/2024-03-07_05-30-00.yaml
# File not found: D:/data/2024-11/2024-03-08_05-30-00.yaml
# File not found: D:/data/2024-11/2024-03-09_05-30-00.yaml
# File not found: D:/data/2024-11/2024-03-10_05-30-00.yaml
# File not found: D:/data/2024-11/2024-03-11_05-30-00.yaml
# File not found: D:/data/2024-11/2024-03-12_05-30-00.yaml
# File not found: D:/data/2024-11/2024-03-13_05-30-00.yaml
# File not found: D:/data/2024-11/2024-03-14_05-30-00.yaml
# File not found: D:/data/2024-11/2024-03-15_05-30-00.yaml
# File not found: D:/data/2024-11/2024-03-16_05-30-00.yaml
# File not found: D:/data/2024-11/2024-03-17_05-30-00.yaml
# File not found: D:/data/2024-11/2024-03-18_05-30-00.yaml
# File not found: D:/data/2024-11/2024-03-19_05-30-00.yaml
# File not found: D:/data/2024-11/2024-03-20_05-30-00.yaml
# File not found: D:/data/2024-11/2024-03-21_05-30-00.yaml
# File not found: D:/data/2024-11/2024-03-22_05-30-00.yaml
# File not found: D:/data/2024-11/2024-03-23_05-30-00.yaml
# File not found: D:/data/2024-11/2024-03-24_05-30-00.yaml
# File not found: D:/data/2024-11/2024-03-25_05-30-00.yaml
# File not found: D:/data/2024-11/2024-03-26_05-30-00.yaml
# File not found: D:/data/2024-11/2024-03-27_05-30-00.yaml
# File not found: D:/data/2024-11/2024-03-28_05-30-00.yaml
# File not found: D:/data/2024-11/2024-03-29_05-30-00.yaml
# File not found: D:/data/2024-11/2024-03-30_05-30-00.yaml
# File not found: D:/data/2024-11/2024-03-31_05-30-00.yaml
# File not found: D:/data/2024-11/2024-04-01_05-30-00.yaml
# File not found: D:/data/2024-11/2024-04-02_05-30-00.yaml
# File not found: D:/data/2024-11/2024-04-03_05-30-00.yaml
# File not found: D:/data/2024-11/2024-04-04_05-30-00.yaml
# File not found: D:/data/2024-11/2024-04-05_05-30-00.yaml
# File not found: D:/data/2024-11/2024-04-06_05-30-00.yaml
# File not found: D:/data/2024-11/2024-04-07_05-30-00.yaml
# File not found: D:/data/2024-11/2024-04-08_05-30-00.yaml
# File not found: D:/data/2024-11/2024-04-09_05-30-00.yaml
# File not found: D:/data/2024-11/2024-04-10_05-30-00.yaml
# File not found: D:/data/2024-11/2024-04-11_05-30-00.yaml
# File not found: D:/data/2024-11/2024-04-12_05-30-00.yaml
# File not found: D:/data/2024-11/2024-04-13_05-30-00.yaml
# File not found: D:/data/2024-11/2024-04-14_05-30-00.yaml
# File not found: D:/data/2024-11/2024-04-15_05-30-00.yaml
# File not found: D:/data/2024-11/2024-04-16_05-30-00.yaml
# File not found: D:/data/2024-11/2024-04-17_05-30-00.yaml
# File not found: D:/data/2024-11/2024-04-18_05-30-00.yaml
# File not found: D:/data/2024-11/2024-04-19_05-30-00.yaml
# File not found: D:/data/2024-11/2024-04-20_05-30-00.yaml
# File not found: D:/data/2024-11/2024-04-21_05-30-00.yaml
# File not found: D:/data/2024-11/2024-04-22_05-30-00.yaml
# File not found: D:/data/2024-11/2024-04-23_05-30-00.yaml
# File not found: D:/data/2024-11/2024-04-24_05-30-00.yaml
# File not found: D:/data/2024-11/2024-04-25_05-30-00.yaml
# File not found: D:/data/2024-11/2024-04-26_05-30-00.yaml
# File not found: D:/data/2024-11/2024-04-27_05-30-00.yaml
# File not found: D:/data/2024-11/2024-04-28_05-30-00.yaml
# File not found: D:/data/2024-11/2024-04-29_05-30-00.yaml
# File not found: D:/data/2024-11/2024-04-30_05-30-00.yaml
# File not found: D:/data/2024-11/2024-05-01_05-30-00.yaml
# File not found: D:/data/2024-11/2024-05-02_05-30-00.yaml
# File not found: D:/data/2024-11/2024-05-03_05-30-00.yaml
# File not found: D:/data/2024-11/2024-05-04_05-30-00.yaml
# File not found: D:/data/2024-11/2024-05-05_05-30-00.yaml
# File not found: D:/data/2024-11/2024-05-06_05-30-00.yaml
# File not found: D:/data/2024-11/2024-05-07_05-30-00.yaml
# File not found: D:/data/2024-11/2024-05-08_05-30-00.yaml
# File not found: D:/data/2024-11/2024-05-09_05-30-00.yaml
# File not found: D:/data/2024-11/2024-05-10_05-30-00.yaml
# File not found: D:/data/2024-11/2024-05-11_05-30-00.yaml
# File not found: D:/data/2024-11/2024-05-12_05-30-00.yaml
# File not found: D:/data/2024-11/2024-05-13_05-30-00.yaml
# File not found: D:/data/2024-11/2024-05-14_05-30-00.yaml
# File not found: D:/data/2024-11/2024-05-15_05-30-00.yaml
# File not found: D:/data/2024-11/2024-05-16_05-30-00.yaml
# File not found: D:/data/2024-11/2024-05-17_05-30-00.yaml
# File not found: D:/data/2024-11/2024-05-18_05-30-00.yaml
# File not found: D:/data/2024-11/2024-05-19_05-30-00.yaml
# File not found: D:/data/2024-11/2024-05-20_05-30-00.yaml
# File not found: D:/data/2024-11/2024-05-21_05-30-00.yaml
# File not found: D:/data/2024-11/2024-05-22_05-30-00.yaml
# File not found: D:/data/2024-11/2024-05-23_05-30-00.yaml
# File not found: D:/data/2024-11/2024-05-24_05-30-00.yaml
# File not found: D:/data/2024-11/2024-05-25_05-30-00.yaml
# File not found: D:/data/2024-11/2024-05-26_05-30-00.yaml
# File not found: D:/data/2024-11/2024-05-27_05-30-00.yaml
# File not found: D:/data/2024-11/2024-05-28_05-30-00.yaml
# File not found: D:/data/2024-11/2024-05-29_05-30-00.yaml
# File not found: D:/data/2024-11/2024-05-30_05-30-00.yaml
# File not found: D:/data/2024-11/2024-05-31_05-30-00.yaml
# File not found: D:/data/2024-11/2024-06-01_05-30-00.yaml
# File not found: D:/data/2024-11/2024-06-02_05-30-00.yaml
# File not found: D:/data/2024-11/2024-06-03_05-30-00.yaml
# File not found: D:/data/2024-11/2024-06-04_05-30-00.yaml
# File not found: D:/data/2024-11/2024-06-05_05-30-00.yaml
# File not found: D:/data/2024-11/2024-06-06_05-30-00.yaml
# File not found: D:/data/2024-11/2024-06-07_05-30-00.yaml
# File not found: D:/data/2024-11/2024-06-08_05-30-00.yaml
# File not found: D:/data/2024-11/2024-06-09_05-30-00.yaml
# File not found: D:/data/2024-11/2024-06-10_05-30-00.yaml
# File not found: D:/data/2024-11/2024-06-11_05-30-00.yaml
# File not found: D:/data/2024-11/2024-06-12_05-30-00.yaml
# File not found: D:/data/2024-11/2024-06-13_05-30-00.yaml
# File not found: D:/data/2024-11/2024-06-14_05-30-00.yaml
# File not found: D:/data/2024-11/2024-06-15_05-30-00.yaml
# File not found: D:/data/2024-11/2024-06-16_05-30-00.yaml
# File not found: D:/data/2024-11/2024-06-17_05-30-00.yaml
# File not found: D:/data/2024-11/2024-06-18_05-30-00.yaml
# File not found: D:/data/2024-11/2024-06-19_05-30-00.yaml
# File not found: D:/data/2024-11/2024-06-20_05-30-00.yaml
# File not found: D:/data/2024-11/2024-06-21_05-30-00.yaml
# File not found: D:/data/2024-11/2024-06-22_05-30-00.yaml
# File not found: D:/data/2024-11/2024-06-23_05-30-00.yaml
# File not found: D:/data/2024-11/2024-06-24_05-30-00.yaml
# File not found: D:/data/2024-11/2024-06-25_05-30-00.yaml
# File not found: D:/data/2024-11/2024-06-26_05-30-00.yaml
# File not found: D:/data/2024-11/2024-06-27_05-30-00.yaml
# File not found: D:/data/2024-11/2024-06-28_05-30-00.yaml
# File not found: D:/data/2024-11/2024-06-29_05-30-00.yaml
# File not found: D:/data/2024-11/2024-06-30_05-30-00.yaml
# File not found: D:/data/2024-11/2024-07-01_05-30-00.yaml
# File not found: D:/data/2024-11/2024-07-02_05-30-00.yaml
# File not found: D:/data/2024-11/2024-07-03_05-30-00.yaml
# File not found: D:/data/2024-11/2024-07-04_05-30-00.yaml
# File not found: D:/data/2024-11/2024-07-05_05-30-00.yaml
# File not found: D:/data/2024-11/2024-07-06_05-30-00.yaml
# File not found: D:/data/2024-11/2024-07-07_05-30-00.yaml
# File not found: D:/data/2024-11/2024-07-08_05-30-00.yaml
# File not found: D:/data/2024-11/2024-07-09_05-30-00.yaml
# File not found: D:/data/2024-11/2024-07-10_05-30-00.yaml
# File not found: D:/data/2024-11/2024-07-11_05-30-00.yaml
# File not found: D:/data/2024-11/2024-07-12_05-30-00.yaml
# File not found: D:/data/2024-11/2024-07-13_05-30-00.yaml
# File not found: D:/data/2024-11/2024-07-14_05-30-00.yaml
# File not found: D:/data/2024-11/2024-07-15_05-30-00.yaml
# File not found: D:/data/2024-11/2024-07-16_05-30-00.yaml
# File not found: D:/data/2024-11/2024-07-17_05-30-00.yaml
# File not found: D:/data/2024-11/2024-07-18_05-30-00.yaml
# File not found: D:/data/2024-11/2024-07-19_05-30-00.yaml
# File not found: D:/data/2024-11/2024-07-20_05-30-00.yaml
# File not found: D:/data/2024-11/2024-07-21_05-30-00.yaml
# File not found: D:/data/2024-11/2024-07-22_05-30-00.yaml
# File not found: D:/data/2024-11/2024-07-23_05-30-00.yaml
# File not found: D:/data/2024-11/2024-07-24_05-30-00.yaml
# File not found: D:/data/2024-11/2024-07-25_05-30-00.yaml
# File not found: D:/data/2024-11/2024-07-26_05-30-00.yaml
# File not found: D:/data/2024-11/2024-07-27_05-30-00.yaml
# File not found: D:/data/2024-11/2024-07-28_05-30-00.yaml
# File not found: D:/data/2024-11/2024-07-29_05-30-00.yaml
# File not found: D:/data/2024-11/2024-07-30_05-30-00.yaml
# File not found: D:/data/2024-11/2024-07-31_05-30-00.yaml
# File not found: D:/data/2024-11/2024-08-01_05-30-00.yaml
# File not found: D:/data/2024-11/2024-08-02_05-30-00.yaml
# File not found: D:/data/2024-11/2024-08-03_05-30-00.yaml
# File not found: D:/data/2024-11/2024-08-04_05-30-00.yaml
# File not found: D:/data/2024-11/2024-08-05_05-30-00.yaml
# File not found: D:/data/2024-11/2024-08-06_05-30-00.yaml
# File not found: D:/data/2024-11/2024-08-07_05-30-00.yaml
# File not found: D:/data/2024-11/2024-08-08_05-30-00.yaml
# File not found: D:/data/2024-11/2024-08-09_05-30-00.yaml
# File not found: D:/data/2024-11/2024-08-10_05-30-00.yaml
# File not found: D:/data/2024-11/2024-08-11_05-30-00.yaml
# File not found: D:/data/2024-11/2024-08-12_05-30-00.yaml
# File not found: D:/data/2024-11/2024-08-13_05-30-00.yaml
# File not found: D:/data/2024-11/2024-08-14_05-30-00.yaml
# File not found: D:/data/2024-11/2024-08-15_05-30-00.yaml
# File not found: D:/data/2024-11/2024-08-16_05-30-00.yaml
# File not found: D:/data/2024-11/2024-08-17_05-30-00.yaml
# File not found: D:/data/2024-11/2024-08-18_05-30-00.yaml
# File not found: D:/data/2024-11/2024-08-19_05-30-00.yaml
# File not found: D:/data/2024-11/2024-08-20_05-30-00.yaml
# File not found: D:/data/2024-11/2024-08-21_05-30-00.yaml
# File not found: D:/data/2024-11/2024-08-22_05-30-00.yaml
# File not found: D:/data/2024-11/2024-08-23_05-30-00.yaml
# File not found: D:/data/2024-11/2024-08-24_05-30-00.yaml
# File not found: D:/data/2024-11/2024-08-25_05-30-00.yaml
# File not found: D:/data/2024-11/2024-08-26_05-30-00.yaml
# File not found: D:/data/2024-11/2024-08-27_05-30-00.yaml
# File not found: D:/data/2024-11/2024-08-28_05-30-00.yaml
# File not found: D:/data/2024-11/2024-08-29_05-30-00.yaml
# File not found: D:/data/2024-11/2024-08-30_05-30-00.yaml
# File not found: D:/data/2024-11/2024-08-31_05-30-00.yaml
# File not found: D:/data/2024-11/2024-09-01_05-30-00.yaml
# File not found: D:/data/2024-11/2024-09-02_05-30-00.yaml
# File not found: D:/data/2024-11/2024-09-03_05-30-00.yaml
# File not found: D:/data/2024-11/2024-09-04_05-30-00.yaml
# File not found: D:/data/2024-11/2024-09-05_05-30-00.yaml
# File not found: D:/data/2024-11/2024-09-06_05-30-00.yaml
# File not found: D:/data/2024-11/2024-09-07_05-30-00.yaml
# File not found: D:/data/2024-11/2024-09-08_05-30-00.yaml
# File not found: D:/data/2024-11/2024-09-09_05-30-00.yaml
# File not found: D:/data/2024-11/2024-09-10_05-30-00.yaml
# File not found: D:/data/2024-11/2024-09-11_05-30-00.yaml
# File not found: D:/data/2024-11/2024-09-12_05-30-00.yaml
# File not found: D:/data/2024-11/2024-09-13_05-30-00.yaml
# File not found: D:/data/2024-11/2024-09-14_05-30-00.yaml
# File not found: D:/data/2024-11/2024-09-15_05-30-00.yaml
# File not found: D:/data/2024-11/2024-09-16_05-30-00.yaml
# File not found: D:/data/2024-11/2024-09-17_05-30-00.yaml
# File not found: D:/data/2024-11/2024-09-18_05-30-00.yaml
# File not found: D:/data/2024-11/2024-09-19_05-30-00.yaml
# File not found: D:/data/2024-11/2024-09-20_05-30-00.yaml
# File not found: D:/data/2024-11/2024-09-21_05-30-00.yaml
# File not found: D:/data/2024-11/2024-09-22_05-30-00.yaml
# File not found: D:/data/2024-11/2024-09-23_05-30-00.yaml
# File not found: D:/data/2024-11/2024-09-24_05-30-00.yaml
# File not found: D:/data/2024-11/2024-09-25_05-30-00.yaml
# File not found: D:/data/2024-11/2024-09-26_05-30-00.yaml
# File not found: D:/data/2024-11/2024-09-27_05-30-00.yaml
# File not found: D:/data/2024-11/2024-09-28_05-30-00.yaml
# File not found: D:/data/2024-11/2024-09-29_05-30-00.yaml
# File not found: D:/data/2024-11/2024-09-30_05-30-00.yaml
# File not found: D:/data/2024-11/2024-10-01_05-30-00.yaml
# File not found: D:/data/2024-11/2024-10-02_05-30-00.yaml
# File not found: D:/data/2024-11/2024-10-03_05-30-00.yaml
# File not found: D:/data/2024-11/2024-10-04_05-30-00.yaml
# File not found: D:/data/2024-11/2024-10-05_05-30-00.yaml
# File not found: D:/data/2024-11/2024-10-06_05-30-00.yaml
# File not found: D:/data/2024-11/2024-10-07_05-30-00.yaml
# File not found: D:/data/2024-11/2024-10-08_05-30-00.yaml
# File not found: D:/data/2024-11/2024-10-09_05-30-00.yaml
# File not found: D:/data/2024-11/2024-10-10_05-30-00.yaml
# File not found: D:/data/2024-11/2024-10-11_05-30-00.yaml
# File not found: D:/data/2024-11/2024-10-12_05-30-00.yaml
# File not found: D:/data/2024-11/2024-10-13_05-30-00.yaml
# File not found: D:/data/2024-11/2024-10-14_05-30-00.yaml
# File not found: D:/data/2024-11/2024-10-15_05-30-00.yaml
# File not found: D:/data/2024-11/2024-10-16_05-30-00.yaml
# File not found: D:/data/2024-11/2024-10-17_05-30-00.yaml
# File not found: D:/data/2024-11/2024-10-18_05-30-00.yaml
# File not found: D:/data/2024-11/2024-10-19_05-30-00.yaml
# File not found: D:/data/2024-11/2024-10-20_05-30-00.yaml
# File not found: D:/data/2024-11/2024-10-21_05-30-00.yaml
# File not found: D:/data/2024-11/2024-10-22_05-30-00.yaml
# File not found: D:/data/2024-11/2024-10-23_05-30-00.yaml
# File not found: D:/data/2024-11/2024-10-24_05-30-00.yaml
# File not found: D:/data/2024-11/2024-10-25_05-30-00.yaml
# File not found: D:/data/2024-11/2024-10-26_05-30-00.yaml
# File not found: D:/data/2024-11/2024-10-27_05-30-00.yaml
# File not found: D:/data/2024-11/2024-10-28_05-30-00.yaml
# File not found: D:/data/2024-11/2024-10-29_05-30-00.yaml
# File not found: D:/data/2024-11/2024-10-30_05-30-00.yaml
# File not found: D:/data/2024-11/2024-10-31_05-30-00.yaml
# File not found: D:/data/2024-11/2024-11-02_05-30-00.yaml
# File not found: D:/data/2024-11/2024-11-03_05-30-00.yaml
# File not found: D:/data/2024-11/2024-11-09_05-30-00.yaml
# File not found: D:/data/2024-11/2024-11-10_05-30-00.yaml
# File not found: D:/data/2024-11/2024-11-15_05-30-00.yaml
# File not found: D:/data/2024-11/2024-11-16_05-30-00.yaml
# File not found: D:/data/2024-11/2024-11-17_05-30-00.yaml
# File not found: D:/data/2024-11/2024-11-20_05-30-00.yaml
#        Ticker    close                 date    high      low    month    open  \
# 0        SBIN   602.95  2023-10-03 05:30:00   604.9   589.60  2023-10   596.6
# 1  BAJFINANCE  7967.60  2023-10-03 05:30:00  7975.5  7755.00  2023-10  7780.8
# 2       TITAN  3196.25  2023-10-03 05:30:00  3212.5  3114.40  2023-10  3148.8
# 3         ITC   439.75  2023-10-03 05:30:00   442.9   439.25  2023-10   441.0
# 4         TCS  3513.85  2023-10-03 05:30:00  3534.2  3480.10  2023-10  3534.2
#
#      volume
# 0  15322196
# 1    944555
# 2   1007308
# 3   7481883
# 4   1948148

# %%
# Volatility Analysis (Standard deviation of daily returns)

if 'close' in wholedf.columns:

    # Sort data by Ticker and Date (important for time series analysis)
    wholedf['date'] = pd.to_datetime(wholedf['date']) 

    wholedf = wholedf.sort_values(by=['Ticker', 'date'])
    
    # Calculate daily returns using the formula: (Close Price - Previous Close Price) / Previous Close Price
    wholedf['Daily_Return'] = (wholedf['close'] - wholedf['close'].shift(1)) / wholedf['close'].shift(1)

    # Calculate volatility as the standard deviation of daily returns for each ticker
    volatility = wholedf.groupby('Ticker')['Daily_Return'].std()

    # Dataframe with ticker and volatility
    volatility = pd.DataFrame(volatility).reset_index()
    volatility.columns = ['Ticker', 'Volatility']

    # Print the volatility DataFrame
    print(volatility)

    # Save volatility data to CSV
    volatility.to_csv("Volatility.csv", index=False)
# Out:
#         Ticker  Volatility
# 0     ADANIENT    0.028601
# 1   ADANIPORTS    0.045443
# 2   APOLLOHOSP    0.208282
# 3   ASIANPAINT    0.034589
# 4     AXISBANK    0.037751
# 5   BAJAJ-AUTO    0.201852
# 6   BAJAJFINSV    0.051545
# 7   BAJFINANCE    0.236561
# 8          BEL    0.062732
# 9   BHARTIARTL    0.136724
# 10        BPCL    0.057403
# 11   BRITANNIA    0.873939
# 12       CIPLA    0.047786
# 13   COALINDIA    0.052337
# 14     DRREDDY    0.097978
# 15   EICHERMOT    0.105553
# 16      GRASIM    0.039377
# 17     HCLTECH    0.034262
# 18    HDFCBANK    0.018196
# 19    HDFCLIFE    0.040548
# 20  HEROMOTOCO    0.201252
# 21    HINDALCO    0.056937
# 22  HINDUNILVR    0.165760
# 23   ICICIBANK    0.038753
# 24  INDUSINDBK    0.020452
# 25        INFY    0.029615
# 26         ITC    0.047173
# 27    JSWSTEEL    0.040359
# 28   KOTAKBANK    0.047668
# 29          LT    0.047286
# 30         M&M    0.039188
# 31      MARUTI    0.145067
# 32   NESTLEIND    0.048996
# 33        NTPC    0.056518
# 34        ONGC    0.036877
# 35   POWERGRID    0.021769
# 36    RELIANCE    0.145390
# 37     SBILIFE    0.015137
# 38        SBIN    0.039602
# 39  SHRIRAMFIN    0.083185
# 40   SUNPHARMA    0.037546
# 41  TATACONSUM    0.034253
# 42  TATAMOTORS    0.027140
# 43   TATASTEEL    0.052993
# 44         TCS    1.401027
# 45       TECHM    0.045334
# 46       TITAN    0.051169
# 47       TRENT    0.032319
# 48  ULTRACEMCO    0.020475
# 49       WIPRO    0.059899

# %%
# Top 10 Most Volatile Stocks

# Sort the volatility DataFrame in descending order and select top 10
top_10_volatility = volatility.sort_values(by='Volatility', ascending=False).head(10)
print(top_10_volatility)

# Save top 10 volatility data to CSV
top_10_volatility.to_csv("Top_10_Volatile_Stocks.csv", index=False)
# Out:
#         Ticker  Volatility
# 44         TCS    1.401027
# 11   BRITANNIA    0.873939
# 7   BAJFINANCE    0.236561
# 2   APOLLOHOSP    0.208282
# 5   BAJAJ-AUTO    0.201852
# 20  HEROMOTOCO    0.201252
# 22  HINDUNILVR    0.165760
# 36    RELIANCE    0.145390
# 31      MARUTI    0.145067
# 9   BHARTIARTL    0.136724

# %%
# Altered Top 10 Volatile stocks
import pandas as pd
import matplotlib.pyplot as plt

# Load the dataset
df = pd.read_csv("Combined_Data.csv")

# Date range
start_date = '2023-10-01'
end_date = '2024-11-30'

if 'close' in df.columns:

    # Filter data by date range
    dfs = df[(df['date'] >= start_date) & (df['date'] <= end_date)]

    # Convert date column to datetime format
    dfs['date'] = pd.to_datetime(dfs['date'])
    
    # Sort the filtered dataframe by Ticker and Date
    dfs = dfs.sort_values(by=['Ticker', 'date'])
    
    # Calculate daily returns: (Close Price - Previous Close Price) / Previous Close Price
    dfs['Daily_Return'] = (dfs['close'] - dfs['close'].shift(1)) / dfs['close'].shift(1)

    # Calculate volatility (standard deviation of daily returns) for each ticker
    volatility = dfs.groupby('Ticker')['Daily_Return'].std()

    # Create a DataFrame with Ticker and its corresponding Volatility
    volatility_df = pd.DataFrame(volatility).reset_index()
    volatility_df.columns = ['Ticker', 'Volatility']

    # Sort the volatility in descending order and get the top 10 most volatile stocks
    top_10_volatility = volatility_df.sort_values(by='Volatility', ascending=False).head(10)

    # Print the top 10 most volatile stocks
    print(top_10_volatility)

    # Save the top 10 volatility data to a CSV file
    top_10_volatility.to_csv("Top_10_Vol_Stocks.csv", index=False)

    # Plot a bar chart to visualize the volatility of the top 10 most volatile stocks
    plt.figure(figsize=(10,6))
    plt.bar(top_10_volatility['Ticker'], top_10_volatility['Volatility'], color='skyblue')
    plt.title('Top 10 Most Volatile Stocks')
    plt.xlabel('Stock Ticker')
    plt.ylabel('Volatility (Standard Deviation of Daily Returns)')
    plt.xticks(rotation=45)
    plt.tight_layout()
    plt.show()

else:
    print("Price column not found in the dataset. Please check the column name for price.")
# Out:
#         Ticker  Volatility
# 44         TCS    1.401027
# 11   BRITANNIA    0.873939
# 7   BAJFINANCE    0.236561
# 2   APOLLOHOSP    0.208282
# 5   BAJAJ-AUTO    0.201852
# 20  HEROMOTOCO    0.201252
# 22  HINDUNILVR    0.165760
# 36    RELIANCE    0.145390
# 31      MARUTI    0.145067
# 9   BHARTIARTL    0.136724

# %%
# Cumulative Return Over Time:

import pandas as pd


# Convert 'date' column to datetime
wholedf['date'] = pd.to_datetime(wholedf['date'])

# Filter data for the specified period: from October 2023 to October 2024
start_date = "2023-10-01"
end_date = "2024-11-31"

data = wholedf[(wholedf['date'] >= start_date) & (wholedf['date'] <= end_date)]

# Extract stock prices on the two key dates (Oct 2023 and Oct 2024)
# First, filter the data for October 2023 and October 2024
october_2023_data = data[data['date'].dt.month == 10][data['date'].dt.year == 2023]
november_2024_data = data[data['date'].dt.month == 11][data['date'].dt.year == 2024]

# Get the prices for each stock (ticker) on both dates (October 2023 and October 2024)
oct_2023_prices = october_2023_data.groupby('Ticker')[['open', 'close', 'high', 'low']].first()  # First entry in October 2023
nov_2024_prices = november_2024_data.groupby('Ticker')[['open', 'close', 'high', 'low']].last()  # Last entry in October 2024

# Merge the two DataFrames to get both prices for each stock
price_comparison = pd.DataFrame({
    'Oct_2023_Price_Open': oct_2023_prices['open'],
    'Oct_2023_Price_Close': oct_2023_prices['close'],
    'Oct_2023_Price_High': oct_2023_prices['high'],
    'Oct_2023_Price_Low': oct_2023_prices['low'],
    'Nov_2024_Price_Open': nov_2024_prices['open'],
    'Nov_2024_Price_Close': nov_2024_prices['close'],
    'Nov_2024_Price_High': nov_2024_prices['high'],
    'Nov_2024_Price_Low': nov_2024_prices['low']
})

# Calculate the Cumulative_return for each stock over the period
price_comparison['cumulative_return'] = (price_comparison['Nov_2024_Price_Close'] - price_comparison['Oct_2023_Price_Close'])/price_comparison['Oct_2023_Price_Close'] * 100

# Reset index to move 'Ticker' from the index to a column(The Ticker was part of the index after the groupby(), so I added price_comparison.reset_index(inplace=True) to move it back to a column.)
price_comparison.reset_index(inplace=True)

# Keep only the 'Ticker' and 'cumulative_return' columns
price_comparison = price_comparison[['Ticker', 'cumulative_return']]

# Print the price comparison DataFrame
print(price_comparison)

# Save the price comparison data to CSV
price_comparison.to_csv("CumulativeReturn.csv", index=False)
# Out:
#         Ticker  cumulative_return
# 0     ADANIENT          24.381611
# 1   ADANIPORTS          67.933606
# 2   APOLLOHOSP          36.404927
# 3   ASIANPAINT          -5.374426
# 4     AXISBANK          12.424956
# 5   BAJAJ-AUTO          98.161050
# 6   BAJAJFINSV          12.260978
# 7   BAJFINANCE         -12.708971
# 8          BEL         107.291667
# 9   BHARTIARTL          76.521128
# 10        BPCL          82.388095
# 11   BRITANNIA          28.630059
# 12       CIPLA          19.906155
# 13   COALINDIA          53.871189
# 14     DRREDDY          14.419503
# 15   EICHERMOT          45.290028
# 16      GRASIM          39.643335
# 17     HCLTECH          48.445951
# 18    HDFCBANK          15.022711
# 19    HDFCLIFE          14.758109
# 20  HEROMOTOCO          62.796790
# 21    HINDALCO          43.431607
# 22  HINDUNILVR           3.485358
# 23   ICICIBANK          39.545890
# 24  INDUSINDBK         -26.403790
# 25        INFY          25.669456
# 26         ITC          11.779420
# 27    JSWSTEEL          24.284323
# 28   KOTAKBANK           0.437162
# 29          LT          10.903766
# 30         M&M          76.122024
# 31      MARUTI           8.790556
# 32   NESTLEIND           2.006704
# 33        NTPC          69.361526
# 34        ONGC          41.738895
# 35   POWERGRID          59.584064
# 36    RELIANCE          15.945405
# 37     SBILIFE          25.664436
# 38        SBIN          36.404345
# 39  SHRIRAMFIN          65.758735
# 40   SUNPHARMA          62.258531
# 41  TATACONSUM          18.752903
# 42  TATAMOTORS          35.417842
# 43   TATASTEEL          16.382812
# 44         TCS          16.244290
# 45       TECHM          38.542181
# 46       TITAN           3.510364
# 47       TRENT         252.214560
# 48  ULTRACEMCO          34.921552
# 49       WIPRO          39.412998
# C:\Users\ASHWINI MURALIDHARAN\AppData\Local\Temp\ipykernel_65416\105651700.py:17: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   october_2023_data = data[data['date'].dt.month == 10][data['date'].dt.year == 2023]
# C:\Users\ASHWINI MURALIDHARAN\AppData\Local\Temp\ipykernel_65416\105651700.py:18: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   november_2024_data = data[data['date'].dt.month == 10][data['date'].dt.year == 2024]

# %%
# Cumulative Return for Top 5 Performing Stocks:
# Sort the cumulative return DataFrame in descending order and select top 5
top_5_performing_stocks = price_comparison.sort_values(by='cumulative_return', ascending=False).head(5)
print(top_5_performing_stocks)
# Save top 5 performing stocks data to CSV
top_5_performing_stocks.to_csv("Top_5_Performing_Stocks.csv", index=False)
# Out:
#         Ticker  cumulative_return
# 47       TRENT         252.214560
# 8          BEL         107.291667
# 5   BAJAJ-AUTO          98.161050
# 10        BPCL          82.388095
# 9   BHARTIARTL          76.521128

# %%
# Alter final code 
import pandas as pd
import matplotlib.pyplot as plt

# Load the dataset
df = pd.read_csv("Combined_Data.csv")

# Date range for filtering the data
start_date = '2023-10-01'
end_date = '2024-10-01'

if 'close' in df.columns:

    # Filter the data by the date range
    dfs = df[(df['date'] >= start_date) & (df['date'] <= end_date)]

    # Convert the date column to datetime format
    dfs['date'] = pd.to_datetime(dfs['date'])
    
    # Sort the dataframe by Ticker and Date
    dfs = dfs.sort_values(by=['Ticker', 'date'])
    
    # Calculate daily returns: (Close Price - Previous Close Price) / Previous Close Price
    dfs['Daily_Return'] = (dfs['close'] - dfs['close'].shift(1)) / dfs['close'].shift(1)
    
    # Calculate cumulative return for each ticker by applying a running total of daily returns
    dfs['Cumulative_Return'] = (1 + dfs['Daily_Return']).groupby(dfs['Ticker']).cumprod() - 1

    # Get the cumulative return for each stock at the end of the period (final cumulative return)
    cumulative_returns = dfs.groupby('Ticker')['Cumulative_Return'].last()

    # Identify the top 5 performing stocks based on final cumulative return
    Top_5_stocks = cumulative_returns.sort_values(ascending=False).head(5)
     

    # Print the top 5 performing stocks
    print("Top 5 Performing Stocks Based on Cumulative Return:")
    print(Top_5_stocks)

    # Save it to csv file
    Top_5_stocks.to_csv('Top_5_stocks.csv')

    # Plot the cumulative return over time for the top 5 performing stocks
    plt.figure(figsize=(10, 6))

    # Loop through each of the top 5 stocks
    for ticker in Top_5_stocks.index:
        stock_data = dfs[dfs['Ticker'] == ticker]
        plt.plot(stock_data['date'], stock_data['Cumulative_Return'], label=ticker)

    # Title and labels
    plt.title('Top 5 Performing Stocks: Cumulative Return Over Time (2023-10-01 to 2024-10-01)')
    plt.xlabel('Date')
    plt.ylabel('Cumulative Return')
    plt.legend(title='Stock Ticker')
    plt.xticks(rotation=45)
    plt.tight_layout()
    plt.show()

else:
    print("Price column not found in the dataset. Please check the column name for price.")
# Out:
# C:\Users\ASHWINI MURALIDHARAN\AppData\Local\Temp\ipykernel_86960\3963682869.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfs['date'] = pd.to_datetime(dfs['date'])
# Top 5 Performing Stocks Based on Cumulative Return:
# Ticker
# TCS           24.324829
# BRITANNIA     16.132450
# BAJAJ-AUTO     9.019437
# HEROMOTOCO     6.955989
# BHARTIARTL     4.996317
# Name: Cumulative_Return, dtype: float64

# %%
#Sector-wise performance analysis

import pandas as pd

# Read the sector data and combined stock data
sector_data = pd.read_csv("Sector_data - Sheet1.csv")
combined_data = pd.read_csv("Combined_Data.csv")

# Clean up ticker symbols in sector data (strip spaces and extract the symbol after the colon)
sector_data['Symbol'] = sector_data['Symbol'].str.strip().str.upper()
sector_data['Symbol'] = sector_data['Symbol'].str.extract(r':\s*([A-Za-z0-9\-]+)')[0]

# Clean ticker symbols in combined data
combined_data['Ticker'] = combined_data['Ticker'].str.strip().str.upper()

# Ensure 'date' column in combined_data is in datetime format
combined_data['date'] = pd.to_datetime(combined_data['date'], errors='coerce')

# Check if there are any invalid dates and handle them
if combined_data['date'].isnull().any():
    print("Warning: There are invalid or missing dates in the 'Date' column.")

# Define the start and end date for the period (2023-10-01 to 2024-11-30)
start_date = pd.to_datetime('2023-10-01')
end_date = pd.to_datetime('2024-11-30')

# Filter data between the start and end dates
recent_data = combined_data[(combined_data['date'] >= start_date) & (combined_data['date'] <= end_date)]

# Sort by Ticker and Date, and drop duplicates to retain the first and last prices
recent_data_sorted = recent_data.sort_values(by=['Ticker', 'date'])
recent_data_first_last = recent_data_sorted.groupby('Ticker').agg(
    first_price=('close', 'first'),
    last_price=('close', 'last')
).reset_index()

# Calculate the 1-year return for each ticker
recent_data_first_last['1_year_return'] = (recent_data_first_last['last_price'] - recent_data_first_last['first_price']) / recent_data_first_last['first_price'] * 100

# Merge with sector data to get the sector information
sector_performance = pd.merge(recent_data_first_last, sector_data[['Symbol', 'sector']], left_on='Ticker', right_on='Symbol', how='left')

# Group by sector and calculate the average 1-year return for each sector
sector_performance_grouped = sector_performance.groupby('sector').agg(
    avg_1_year_return=('1_year_return', 'mean'),
    count_tickers=('Ticker', 'count')
).reset_index()

# Sort sectors by the average 1-year return
sector_performance_grouped_sorted = sector_performance_grouped.sort_values(by='avg_1_year_return', ascending=False)

# Display the final result
print(sector_performance_grouped_sorted)

sector_performance_grouped_sorted.rename(columns={"____sector": "sector"}, inplace=True)

# Save the sector-wise performance data to CSV withoout count_tickers column
sector_performance_grouped_sorted = sector_performance_grouped_sorted.drop(columns=['count_tickers'])
sector_performance_grouped_sorted.to_csv("SectorWisePerformance.csv", index=False)
# Out:
#              sector  avg_1_year_return  count_tickers
# 16        RETAILING         113.305399              2
# 4           DEFENCE         101.760057              1
# 15            POWER          60.184095              2
# 1       AUTOMOBILES          46.236450              5
# 11           MINING          41.846523              1
# 17         SOFTWARE          38.275954              5
# 3            CEMENT          36.970945              1
# 5            ENERGY          36.564788              3
# 12    MISCELLANEOUS          36.103081              2
# 0         ALUMINIUM          35.868320              1
# 19         TEXTILES          35.781988              1
# 14  PHARMACEUTICALS          31.379173              3
# 18            STEEL          19.217125              2
# 6       ENGINEERING          17.253722              1
# 10        INSURANCE          11.767832              2
# 7           FINANCE          11.576063              3
# 2           BANKING          11.380534              6
# 9    FOOD & TOBACCO           4.321734              2
# 8              FMCG          -0.957916              1
# 13           PAINTS         -21.935046              1

# %%
# Stock Price Correlation Analysis
import pandas as pd

# Read the data (assuming combined_data contains the necessary stock data with 'Date' and 'Close' columns)
combined_data = pd.read_csv("Combined_Data.csv")

# Ensure 'Date' is in datetime format
combined_data['date'] = pd.to_datetime(combined_data['date'])

# Pivot the data to get stock prices for each ticker on a particular date
stock_data = combined_data.pivot(index='date', columns='Ticker', values='close')

# Calculate daily percentage change for each stock
daily_pct_change = stock_data.pct_change()

# Calculate the correlation matrix of the daily percentage changes
correlation_matrix = daily_pct_change.corr()

# Display the correlation matrix
print(correlation_matrix)

# Save the correlation matrix to a CSV file
correlation_matrix.to_csv("Correlation_Matrix.csv")
# Out:
# Ticker      ADANIENT  ADANIPORTS  APOLLOHOSP  ASIANPAINT  AXISBANK  \
# Ticker
# ADANIENT    1.000000    0.874233    0.136501    0.291583  0.297736
# ADANIPORTS  0.874233    1.000000    0.168902    0.274045  0.380514
# APOLLOHOSP  0.136501    0.168902    1.000000    0.258055  0.179381
# ASIANPAINT  0.291583    0.274045    0.258055    1.000000  0.126055
# AXISBANK    0.297736    0.380514    0.179381    0.126055  1.000000
# BAJAJ-AUTO  0.201871    0.204456    0.223900    0.167650  0.198477
# BAJAJFINSV  0.356547    0.398041    0.249392    0.248090  0.393683
# BAJFINANCE  0.336031    0.398769    0.223142    0.296922  0.354079
# BEL         0.522680    0.585672    0.224594    0.156953  0.330512
# BHARTIARTL  0.282859    0.316537    0.236810    0.146953  0.238602
# BPCL        0.455289    0.495117    0.174973    0.215787  0.222936
# BRITANNIA   0.130655    0.133400    0.231736    0.426896  0.130775
# CIPLA       0.094238    0.091118    0.231114    0.147018  0.085260
# COALINDIA   0.494534    0.546202    0.243537    0.194986  0.332553
# DRREDDY     0.164552    0.160972    0.235448    0.149961  0.091461
# EICHERMOT   0.331647    0.269610    0.290339    0.257914  0.286161
# GRASIM      0.344468    0.356102    0.258184    0.344453  0.367053
# HCLTECH     0.139916    0.152640    0.279181    0.117484  0.107496
# HDFCBANK    0.338118    0.375305    0.110238    0.264323  0.424931
# HDFCLIFE    0.216839    0.247059    0.141669    0.206022  0.251479
# HEROMOTOCO  0.208576    0.202512    0.248153    0.180187  0.172582
# HINDALCO    0.304966    0.337762    0.062547    0.212252  0.227375
# HINDUNILVR -0.000796    0.002376    0.107865    0.269889  0.009843
# ICICIBANK   0.394584    0.442289    0.164303    0.158839  0.636786
# INDUSINDBK  0.391347    0.422431    0.129152    0.180855  0.339661
# INFY        0.115149    0.149400    0.121671    0.104310  0.086467
# ITC         0.245803    0.273774    0.174046    0.275550  0.275001
# JSWSTEEL    0.405664    0.434606    0.276060    0.333566  0.365966
# KOTAKBANK   0.243752    0.305838    0.139795    0.181202  0.292039
# LT          0.483136    0.513974    0.235883    0.223101  0.352081
# M&M         0.304545    0.319381    0.251029    0.140121  0.235556
# MARUTI      0.315659    0.302342    0.194062    0.260366  0.260371
# NESTLEIND   0.115017    0.087843    0.224446    0.282631  0.100344
# NTPC        0.545960    0.610464    0.194129    0.222064  0.394813
# ONGC        0.484910    0.521803    0.173658    0.128654  0.313449
# POWERGRID   0.403946    0.511696    0.178438    0.111665  0.294693
# RELIANCE    0.487097    0.512736    0.234728    0.294963  0.423456
# SBILIFE     0.289193    0.284613    0.160706    0.220352  0.183053
# SBIN        0.544697    0.579516    0.182850    0.107866  0.516122
# SHRIRAMFIN  0.410298    0.469890    0.291768    0.202540  0.448564
# SUNPHARMA   0.166256    0.215856    0.286227    0.202262  0.143991
# TATACONSUM  0.203847    0.220655    0.096700    0.244278  0.139747
# TATAMOTORS  0.324071    0.339241    0.212357    0.105847  0.232145
# TATASTEEL   0.423563    0.466043    0.254731    0.287050  0.370957
# TCS         0.115790    0.132423    0.106846    0.166699  0.094669
# TECHM       0.141677    0.148034    0.169118    0.162959  0.136469
# TITAN       0.283281    0.296148    0.253361    0.307404  0.145931
# TRENT       0.190412    0.201076    0.089516    0.223094  0.199748
# ULTRACEMCO  0.361152    0.402489    0.272951    0.280647  0.397024
# WIPRO       0.224003    0.238986    0.223738    0.140642  0.207802
#
# Ticker      BAJAJ-AUTO  BAJAJFINSV  BAJFINANCE       BEL  BHARTIARTL  ...  \
# Ticker                                                                ...
# ADANIENT      0.201871    0.356547    0.336031  0.522680    0.282859  ...
# ADANIPORTS    0.204456    0.398041    0.398769  0.585672    0.316537  ...
# APOLLOHOSP    0.223900    0.249392    0.223142  0.224594    0.236810  ...
# ASIANPAINT    0.167650    0.248090    0.296922  0.156953    0.146953  ...
# AXISBANK      0.198477    0.393683    0.354079  0.330512    0.238602  ...
# BAJAJ-AUTO    1.000000    0.237654    0.178554  0.233430    0.262054  ...
# BAJAJFINSV    0.237654    1.000000    0.748723  0.346261    0.257664  ...
# BAJFINANCE    0.178554    0.748723    1.000000  0.315822    0.291641  ...
# BEL           0.233430    0.346261    0.315822  1.000000    0.309294  ...
# BHARTIARTL    0.262054    0.257664    0.291641  0.309294    1.000000  ...
# BPCL          0.215531    0.345286    0.272608  0.505802    0.265020  ...
# BRITANNIA     0.094707    0.225478    0.207936  0.073187    0.121226  ...
# CIPLA         0.043536    0.135928    0.053728  0.082404    0.119963  ...
# COALINDIA     0.225770    0.279739    0.280246  0.620262    0.267037  ...
# DRREDDY       0.104890    0.257756    0.088308  0.131475    0.178094  ...
# EICHERMOT     0.276130    0.241356    0.189578  0.284223    0.294734  ...
# GRASIM        0.200661    0.435099    0.368980  0.337925    0.297192  ...
# HCLTECH       0.124516    0.267826    0.183187  0.224041    0.258437  ...
# HDFCBANK      0.182233    0.318705    0.331632  0.330752    0.211028  ...
# HDFCLIFE      0.191902    0.347351    0.307101  0.251302    0.215032  ...
# HEROMOTOCO    0.406801    0.236211    0.171239  0.087771    0.183911  ...
# HINDALCO      0.216860    0.296242    0.254539  0.375871    0.294149  ...
# HINDUNILVR    0.124955    0.139454    0.127433 -0.058291    0.158531  ...
# ICICIBANK     0.108522    0.415419    0.350008  0.313735    0.366610  ...
# INDUSINDBK    0.206118    0.422960    0.406266  0.308607    0.231639  ...
# INFY         -0.003487    0.241348    0.197446  0.164705    0.288846  ...
# ITC           0.140413    0.303636    0.304404  0.230195    0.260515  ...
# JSWSTEEL      0.223461    0.447526    0.390934  0.458783    0.364830  ...
# KOTAKBANK     0.082628    0.273104    0.315904  0.266514    0.318991  ...
# LT            0.175763    0.398992    0.378919  0.591401    0.323943  ...
# M&M           0.271628    0.337684    0.267973  0.369498    0.291923  ...
# MARUTI        0.342005    0.329276    0.281244  0.224642    0.348079  ...
# NESTLEIND     0.179005    0.273745    0.246975  0.065317    0.106086  ...
# NTPC          0.202560    0.391226    0.328260  0.607886    0.366187  ...
# ONGC          0.187871    0.305737    0.316297  0.572377    0.346411  ...
# POWERGRID     0.168364    0.307034    0.245101  0.544756    0.311228  ...
# RELIANCE      0.246961    0.407201    0.413342  0.492507    0.365995  ...
# SBILIFE       0.190211    0.405717    0.335101  0.209939    0.241723  ...
# SBIN          0.154854    0.419859    0.397696  0.580213    0.290364  ...
# SHRIRAMFIN    0.301142    0.468791    0.461618  0.475480    0.360799  ...
# SUNPHARMA     0.149957    0.213243    0.137262  0.163531    0.272227  ...
# TATACONSUM    0.185135    0.304497    0.236369  0.175809    0.248732  ...
# TATAMOTORS    0.294698    0.280169    0.212748  0.367173    0.269331  ...
# TATASTEEL     0.283691    0.456570    0.381616  0.520365    0.305352  ...
# TCS           0.017591    0.234842    0.174425  0.120758    0.193183  ...
# TECHM         0.037877    0.204276    0.173360  0.222395    0.272352  ...
# TITAN         0.201060    0.329527    0.269039  0.166767    0.276037  ...
# TRENT         0.223399    0.201133    0.229188  0.263415    0.247927  ...
# ULTRACEMCO    0.263342    0.463107    0.434558  0.435501    0.354121  ...
# WIPRO         0.102492    0.306650    0.238516  0.255854    0.259131  ...
#
# Ticker      SUNPHARMA  TATACONSUM  TATAMOTORS  TATASTEEL       TCS     TECHM  \
# Ticker
# ADANIENT     0.166256    0.203847    0.324071   0.423563  0.115790  0.141677
# ADANIPORTS   0.215856    0.220655    0.339241   0.466043  0.132423  0.148034
# APOLLOHOSP   0.286227    0.096700    0.212357   0.254731  0.106846  0.169118
# ASIANPAINT   0.202262    0.244278    0.105847   0.287050  0.166699  0.162959
# AXISBANK     0.143991    0.139747    0.232145   0.370957  0.094669  0.136469
# BAJAJ-AUTO   0.149957    0.185135    0.294698   0.283691  0.017591  0.037877
# BAJAJFINSV   0.213243    0.304497    0.280169   0.456570  0.234842  0.204276
# BAJFINANCE   0.137262    0.236369    0.212748   0.381616  0.174425  0.173360
# BEL          0.163531    0.175809    0.367173   0.520365  0.120758  0.222395
# BHARTIARTL   0.272227    0.248732    0.269331   0.305352  0.193183  0.272352
# BPCL         0.205494    0.156373    0.415679   0.462885  0.175426  0.201632
# BRITANNIA    0.187936    0.405008    0.109019   0.118834  0.117657  0.129664
# CIPLA        0.414759    0.073227    0.068966   0.131112  0.079022  0.052199
# COALINDIA    0.177471    0.213072    0.406315   0.535425  0.095263  0.178173
# DRREDDY      0.396686    0.110615    0.200125   0.207222  0.223212  0.220019
# EICHERMOT    0.175283    0.172375    0.316620   0.314499  0.143776  0.189578
# GRASIM       0.218122    0.282995    0.336304   0.463646  0.179943  0.175110
# HCLTECH      0.156099    0.209540    0.269334   0.268719  0.629079  0.548280
# HDFCBANK     0.071820    0.108654    0.204986   0.380764  0.045286  0.204667
# HDFCLIFE     0.168518    0.214307    0.224166   0.275177  0.115449  0.119529
# HEROMOTOCO   0.220462    0.212351    0.290746   0.287774  0.108665  0.111243
# HINDALCO     0.254427    0.180976    0.364959   0.630099  0.161044  0.236387
# HINDUNILVR   0.051338    0.412071    0.088024   0.084734  0.145345  0.131313
# ICICIBANK    0.202726    0.120592    0.199674   0.345279  0.166489  0.168655
# INDUSINDBK   0.122917    0.273550    0.333359   0.396258  0.085590  0.103153
# INFY         0.143073    0.245193    0.181710   0.180954  0.707884  0.649146
# ITC          0.186995    0.302655    0.188564   0.257269  0.152274  0.217816
# JSWSTEEL     0.252222    0.235532    0.408712   0.794189  0.209291  0.268989
# KOTAKBANK    0.089100    0.197429    0.160206   0.262726  0.115565  0.174738
# LT           0.167209    0.168087    0.352993   0.483848  0.217062  0.210315
# M&M          0.285570    0.169598    0.400987   0.427432  0.174295  0.219419
# MARUTI       0.200872    0.207816    0.405831   0.395828  0.164892  0.147973
# NESTLEIND    0.141183    0.375731    0.147040   0.103308  0.114495  0.054905
# NTPC         0.230246    0.187078    0.409924   0.533943  0.109945  0.189870
# ONGC         0.228145    0.177229    0.436927   0.491860  0.168162  0.233515
# POWERGRID    0.246122    0.150893    0.355057   0.502428  0.097295  0.151609
# RELIANCE     0.293116    0.207763    0.386583   0.441104  0.247971  0.266063
# SBILIFE      0.131142    0.210613    0.224283   0.232113  0.175014  0.154585
# SBIN         0.122857    0.117567    0.363321   0.489624  0.162862  0.193755
# SHRIRAMFIN   0.210963    0.187778    0.362474   0.436920  0.113654  0.227147
# SUNPHARMA    1.000000    0.172295    0.305911   0.260971  0.147690  0.164001
# TATACONSUM   0.172295    1.000000    0.188062   0.225777  0.271634  0.212756
# TATAMOTORS   0.305911    0.188062    1.000000   0.513416  0.248889  0.279026
# TATASTEEL    0.260971    0.225777    0.513416   1.000000  0.235867  0.283648
# TCS          0.147690    0.271634    0.248889   0.235867  1.000000  0.578882
# TECHM        0.164001    0.212756    0.279026   0.283648  0.578882  1.000000
# TITAN        0.214335    0.311262    0.274323   0.293416  0.145475  0.243389
# TRENT        0.256380    0.185995    0.222437   0.218748  0.122021  0.150751
# ULTRACEMCO   0.232441    0.244972    0.353946   0.471722  0.238679  0.269904
# WIPRO        0.192644    0.249107    0.311797   0.331808  0.591427  0.599253
#
# Ticker         TITAN     TRENT  ULTRACEMCO     WIPRO
# Ticker
# ADANIENT    0.283281  0.190412    0.361152  0.224003
# ADANIPORTS  0.296148  0.201076    0.402489  0.238986
# APOLLOHOSP  0.253361  0.089516    0.272951  0.223738
# ASIANPAINT  0.307404  0.223094    0.280647  0.140642
# AXISBANK    0.145931  0.199748    0.397024  0.207802
# BAJAJ-AUTO  0.201060  0.223399    0.263342  0.102492
# BAJAJFINSV  0.329527  0.201133    0.463107  0.306650
# BAJFINANCE  0.269039  0.229188    0.434558  0.238516
# BEL         0.166767  0.263415    0.435501  0.255854
# BHARTIARTL  0.276037  0.247927    0.354121  0.259131
# BPCL        0.275086  0.212755    0.401651  0.211945
# BRITANNIA   0.073109  0.034251    0.181814  0.169110
# CIPLA       0.107529  0.136473    0.133328  0.087595
# COALINDIA   0.238336  0.254629    0.321221  0.235794
# DRREDDY     0.139991  0.168870    0.251558  0.279839
# EICHERMOT   0.268206  0.234639    0.304244  0.262235
# GRASIM      0.368297  0.241469    0.590116  0.245002
# HCLTECH     0.199441  0.207422    0.205442  0.580667
# HDFCBANK    0.188021  0.102739    0.360209  0.193599
# HDFCLIFE    0.226622  0.202129    0.241819  0.194261
# HEROMOTOCO  0.302480  0.218545    0.295383  0.204583
# HINDALCO    0.249438  0.268630    0.313590  0.262244
# HINDUNILVR  0.187477  0.083964    0.165126  0.185425
# ICICIBANK   0.146474  0.121659    0.430208  0.221655
# INDUSINDBK  0.240433  0.199126    0.345066  0.186573
# INFY        0.215072  0.150991    0.224565  0.571208
# ITC         0.318261  0.151491    0.260144  0.233139
# JSWSTEEL    0.322128  0.256977    0.546643  0.360374
# KOTAKBANK   0.168053  0.081005    0.334770  0.245812
# LT          0.231900  0.185279    0.473174  0.319899
# M&M         0.285280  0.249013    0.418644  0.299971
# MARUTI      0.332279  0.183321    0.349174  0.205206
# NESTLEIND   0.236875  0.136674    0.278184  0.149708
# NTPC        0.334051  0.235736    0.448524  0.202935
# ONGC        0.192695  0.211585    0.404519  0.288967
# POWERGRID   0.208609  0.200542    0.396684  0.166631
# RELIANCE    0.329323  0.282779    0.490382  0.364313
# SBILIFE     0.219543  0.170800    0.266797  0.246338
# SBIN        0.223221  0.276491    0.425494  0.243531
# SHRIRAMFIN  0.254687  0.228691    0.468239  0.298607
# SUNPHARMA   0.214335  0.256380    0.232441  0.192644
# TATACONSUM  0.311262  0.185995    0.244972  0.249107
# TATAMOTORS  0.274323  0.222437    0.353946  0.311797
# TATASTEEL   0.293416  0.218748    0.471722  0.331808
# TCS         0.145475  0.122021    0.238679  0.591427
# TECHM       0.243389  0.150751    0.269904  0.599253
# TITAN       1.000000  0.194346    0.353920  0.259623
# TRENT       0.194346  1.000000    0.295226  0.150452
# ULTRACEMCO  0.353920  0.295226    1.000000  0.291504
# WIPRO       0.259623  0.150452    0.291504  1.000000
#
# [50 rows x 50 columns]

# %%
import pandas as pd

# Try reading the data with error handling
try:
    combined_data = pd.read_csv("Combined_Data.csv")
except FileNotFoundError:
    print("Error: The file 'Combined_Data.csv' was not found.")
    # Handle the error, e.g., exit the script or load a different file
    exit()

# Ensure 'Date' is in datetime format
try:
    combined_data['date'] = pd.to_datetime(combined_data['date'])
except KeyError:
    print("Error: 'date' column not found in the data.")
    exit()

# Sanitize ticker symbols by replacing non-alphanumeric characters
try:
    combined_data['Ticker'] = combined_data['Ticker'].apply(lambda x: x.replace('-', '_').replace(' ', '_').replace("'", "''"))
except KeyError:
    print("Error: 'Ticker' column not found in the data.")
    exit()

# Pivot the data to get stock prices for each ticker on a particular date
try:
    stock_data = combined_data.pivot(index='date', columns='Ticker', values='close')
except KeyError:
    print("Error: 'close' or 'Ticker' column missing in the data.")
    exit()

# Calculate daily percentage change for each stock
daily_pct_change = stock_data.pct_change()

# Calculate the correlation matrix of the daily percentage changes
correlation_matrix = daily_pct_change.corr()

# Display the correlation matrix
print("Correlation Matrix of Daily Percentage Changes:")
print(correlation_matrix)

# Save the correlation matrix to a CSV file
correlation_matrix.to_csv("Correlation_Matrix.csv")
# Out:
# Correlation Matrix of Daily Percentage Changes:
# Ticker      ADANIENT  ADANIPORTS  APOLLOHOSP  ASIANPAINT  AXISBANK  \
# Ticker
# ADANIENT    1.000000    0.874233    0.136501    0.291583  0.297736
# ADANIPORTS  0.874233    1.000000    0.168902    0.274045  0.380514
# APOLLOHOSP  0.136501    0.168902    1.000000    0.258055  0.179381
# ASIANPAINT  0.291583    0.274045    0.258055    1.000000  0.126055
# AXISBANK    0.297736    0.380514    0.179381    0.126055  1.000000
# BAJAJFINSV  0.356547    0.398041    0.249392    0.248090  0.393683
# BAJAJ_AUTO  0.201871    0.204456    0.223900    0.167650  0.198477
# BAJFINANCE  0.336031    0.398769    0.223142    0.296922  0.354079
# BEL         0.522680    0.585672    0.224594    0.156953  0.330512
# BHARTIARTL  0.282859    0.316537    0.236810    0.146953  0.238602
# BPCL        0.455289    0.495117    0.174973    0.215787  0.222936
# BRITANNIA   0.130655    0.133400    0.231736    0.426896  0.130775
# CIPLA       0.094238    0.091118    0.231114    0.147018  0.085260
# COALINDIA   0.494534    0.546202    0.243537    0.194986  0.332553
# DRREDDY     0.164552    0.160972    0.235448    0.149961  0.091461
# EICHERMOT   0.331647    0.269610    0.290339    0.257914  0.286161
# GRASIM      0.344468    0.356102    0.258184    0.344453  0.367053
# HCLTECH     0.139916    0.152640    0.279181    0.117484  0.107496
# HDFCBANK    0.338118    0.375305    0.110238    0.264323  0.424931
# HDFCLIFE    0.216839    0.247059    0.141669    0.206022  0.251479
# HEROMOTOCO  0.208576    0.202512    0.248153    0.180187  0.172582
# HINDALCO    0.304966    0.337762    0.062547    0.212252  0.227375
# HINDUNILVR -0.000796    0.002376    0.107865    0.269889  0.009843
# ICICIBANK   0.394584    0.442289    0.164303    0.158839  0.636786
# INDUSINDBK  0.391347    0.422431    0.129152    0.180855  0.339661
# INFY        0.115149    0.149400    0.121671    0.104310  0.086467
# ITC         0.245803    0.273774    0.174046    0.275550  0.275001
# JSWSTEEL    0.405664    0.434606    0.276060    0.333566  0.365966
# KOTAKBANK   0.243752    0.305838    0.139795    0.181202  0.292039
# LT          0.483136    0.513974    0.235883    0.223101  0.352081
# M&M         0.304545    0.319381    0.251029    0.140121  0.235556
# MARUTI      0.315659    0.302342    0.194062    0.260366  0.260371
# NESTLEIND   0.115017    0.087843    0.224446    0.282631  0.100344
# NTPC        0.545960    0.610464    0.194129    0.222064  0.394813
# ONGC        0.484910    0.521803    0.173658    0.128654  0.313449
# POWERGRID   0.403946    0.511696    0.178438    0.111665  0.294693
# RELIANCE    0.487097    0.512736    0.234728    0.294963  0.423456
# SBILIFE     0.289193    0.284613    0.160706    0.220352  0.183053
# SBIN        0.544697    0.579516    0.182850    0.107866  0.516122
# SHRIRAMFIN  0.410298    0.469890    0.291768    0.202540  0.448564
# SUNPHARMA   0.166256    0.215856    0.286227    0.202262  0.143991
# TATACONSUM  0.203847    0.220655    0.096700    0.244278  0.139747
# TATAMOTORS  0.324071    0.339241    0.212357    0.105847  0.232145
# TATASTEEL   0.423563    0.466043    0.254731    0.287050  0.370957
# TCS         0.115790    0.132423    0.106846    0.166699  0.094669
# TECHM       0.141677    0.148034    0.169118    0.162959  0.136469
# TITAN       0.283281    0.296148    0.253361    0.307404  0.145931
# TRENT       0.190412    0.201076    0.089516    0.223094  0.199748
# ULTRACEMCO  0.361152    0.402489    0.272951    0.280647  0.397024
# WIPRO       0.224003    0.238986    0.223738    0.140642  0.207802
#
# Ticker      BAJAJFINSV  BAJAJ_AUTO  BAJFINANCE       BEL  BHARTIARTL  ...  \
# Ticker                                                                ...
# ADANIENT      0.356547    0.201871    0.336031  0.522680    0.282859  ...
# ADANIPORTS    0.398041    0.204456    0.398769  0.585672    0.316537  ...
# APOLLOHOSP    0.249392    0.223900    0.223142  0.224594    0.236810  ...
# ASIANPAINT    0.248090    0.167650    0.296922  0.156953    0.146953  ...
# AXISBANK      0.393683    0.198477    0.354079  0.330512    0.238602  ...
# BAJAJFINSV    1.000000    0.237654    0.748723  0.346261    0.257664  ...
# BAJAJ_AUTO    0.237654    1.000000    0.178554  0.233430    0.262054  ...
# BAJFINANCE    0.748723    0.178554    1.000000  0.315822    0.291641  ...
# BEL           0.346261    0.233430    0.315822  1.000000    0.309294  ...
# BHARTIARTL    0.257664    0.262054    0.291641  0.309294    1.000000  ...
# BPCL          0.345286    0.215531    0.272608  0.505802    0.265020  ...
# BRITANNIA     0.225478    0.094707    0.207936  0.073187    0.121226  ...
# CIPLA         0.135928    0.043536    0.053728  0.082404    0.119963  ...
# COALINDIA     0.279739    0.225770    0.280246  0.620262    0.267037  ...
# DRREDDY       0.257756    0.104890    0.088308  0.131475    0.178094  ...
# EICHERMOT     0.241356    0.276130    0.189578  0.284223    0.294734  ...
# GRASIM        0.435099    0.200661    0.368980  0.337925    0.297192  ...
# HCLTECH       0.267826    0.124516    0.183187  0.224041    0.258437  ...
# HDFCBANK      0.318705    0.182233    0.331632  0.330752    0.211028  ...
# HDFCLIFE      0.347351    0.191902    0.307101  0.251302    0.215032  ...
# HEROMOTOCO    0.236211    0.406801    0.171239  0.087771    0.183911  ...
# HINDALCO      0.296242    0.216860    0.254539  0.375871    0.294149  ...
# HINDUNILVR    0.139454    0.124955    0.127433 -0.058291    0.158531  ...
# ICICIBANK     0.415419    0.108522    0.350008  0.313735    0.366610  ...
# INDUSINDBK    0.422960    0.206118    0.406266  0.308607    0.231639  ...
# INFY          0.241348   -0.003487    0.197446  0.164705    0.288846  ...
# ITC           0.303636    0.140413    0.304404  0.230195    0.260515  ...
# JSWSTEEL      0.447526    0.223461    0.390934  0.458783    0.364830  ...
# KOTAKBANK     0.273104    0.082628    0.315904  0.266514    0.318991  ...
# LT            0.398992    0.175763    0.378919  0.591401    0.323943  ...
# M&M           0.337684    0.271628    0.267973  0.369498    0.291923  ...
# MARUTI        0.329276    0.342005    0.281244  0.224642    0.348079  ...
# NESTLEIND     0.273745    0.179005    0.246975  0.065317    0.106086  ...
# NTPC          0.391226    0.202560    0.328260  0.607886    0.366187  ...
# ONGC          0.305737    0.187871    0.316297  0.572377    0.346411  ...
# POWERGRID     0.307034    0.168364    0.245101  0.544756    0.311228  ...
# RELIANCE      0.407201    0.246961    0.413342  0.492507    0.365995  ...
# SBILIFE       0.405717    0.190211    0.335101  0.209939    0.241723  ...
# SBIN          0.419859    0.154854    0.397696  0.580213    0.290364  ...
# SHRIRAMFIN    0.468791    0.301142    0.461618  0.475480    0.360799  ...
# SUNPHARMA     0.213243    0.149957    0.137262  0.163531    0.272227  ...
# TATACONSUM    0.304497    0.185135    0.236369  0.175809    0.248732  ...
# TATAMOTORS    0.280169    0.294698    0.212748  0.367173    0.269331  ...
# TATASTEEL     0.456570    0.283691    0.381616  0.520365    0.305352  ...
# TCS           0.234842    0.017591    0.174425  0.120758    0.193183  ...
# TECHM         0.204276    0.037877    0.173360  0.222395    0.272352  ...
# TITAN         0.329527    0.201060    0.269039  0.166767    0.276037  ...
# TRENT         0.201133    0.223399    0.229188  0.263415    0.247927  ...
# ULTRACEMCO    0.463107    0.263342    0.434558  0.435501    0.354121  ...
# WIPRO         0.306650    0.102492    0.238516  0.255854    0.259131  ...
#
# Ticker      SUNPHARMA  TATACONSUM  TATAMOTORS  TATASTEEL       TCS     TECHM  \
# Ticker
# ADANIENT     0.166256    0.203847    0.324071   0.423563  0.115790  0.141677
# ADANIPORTS   0.215856    0.220655    0.339241   0.466043  0.132423  0.148034
# APOLLOHOSP   0.286227    0.096700    0.212357   0.254731  0.106846  0.169118
# ASIANPAINT   0.202262    0.244278    0.105847   0.287050  0.166699  0.162959
# AXISBANK     0.143991    0.139747    0.232145   0.370957  0.094669  0.136469
# BAJAJFINSV   0.213243    0.304497    0.280169   0.456570  0.234842  0.204276
# BAJAJ_AUTO   0.149957    0.185135    0.294698   0.283691  0.017591  0.037877
# BAJFINANCE   0.137262    0.236369    0.212748   0.381616  0.174425  0.173360
# BEL          0.163531    0.175809    0.367173   0.520365  0.120758  0.222395
# BHARTIARTL   0.272227    0.248732    0.269331   0.305352  0.193183  0.272352
# BPCL         0.205494    0.156373    0.415679   0.462885  0.175426  0.201632
# BRITANNIA    0.187936    0.405008    0.109019   0.118834  0.117657  0.129664
# CIPLA        0.414759    0.073227    0.068966   0.131112  0.079022  0.052199
# COALINDIA    0.177471    0.213072    0.406315   0.535425  0.095263  0.178173
# DRREDDY      0.396686    0.110615    0.200125   0.207222  0.223212  0.220019
# EICHERMOT    0.175283    0.172375    0.316620   0.314499  0.143776  0.189578
# GRASIM       0.218122    0.282995    0.336304   0.463646  0.179943  0.175110
# HCLTECH      0.156099    0.209540    0.269334   0.268719  0.629079  0.548280
# HDFCBANK     0.071820    0.108654    0.204986   0.380764  0.045286  0.204667
# HDFCLIFE     0.168518    0.214307    0.224166   0.275177  0.115449  0.119529
# HEROMOTOCO   0.220462    0.212351    0.290746   0.287774  0.108665  0.111243
# HINDALCO     0.254427    0.180976    0.364959   0.630099  0.161044  0.236387
# HINDUNILVR   0.051338    0.412071    0.088024   0.084734  0.145345  0.131313
# ICICIBANK    0.202726    0.120592    0.199674   0.345279  0.166489  0.168655
# INDUSINDBK   0.122917    0.273550    0.333359   0.396258  0.085590  0.103153
# INFY         0.143073    0.245193    0.181710   0.180954  0.707884  0.649146
# ITC          0.186995    0.302655    0.188564   0.257269  0.152274  0.217816
# JSWSTEEL     0.252222    0.235532    0.408712   0.794189  0.209291  0.268989
# KOTAKBANK    0.089100    0.197429    0.160206   0.262726  0.115565  0.174738
# LT           0.167209    0.168087    0.352993   0.483848  0.217062  0.210315
# M&M          0.285570    0.169598    0.400987   0.427432  0.174295  0.219419
# MARUTI       0.200872    0.207816    0.405831   0.395828  0.164892  0.147973
# NESTLEIND    0.141183    0.375731    0.147040   0.103308  0.114495  0.054905
# NTPC         0.230246    0.187078    0.409924   0.533943  0.109945  0.189870
# ONGC         0.228145    0.177229    0.436927   0.491860  0.168162  0.233515
# POWERGRID    0.246122    0.150893    0.355057   0.502428  0.097295  0.151609
# RELIANCE     0.293116    0.207763    0.386583   0.441104  0.247971  0.266063
# SBILIFE      0.131142    0.210613    0.224283   0.232113  0.175014  0.154585
# SBIN         0.122857    0.117567    0.363321   0.489624  0.162862  0.193755
# SHRIRAMFIN   0.210963    0.187778    0.362474   0.436920  0.113654  0.227147
# SUNPHARMA    1.000000    0.172295    0.305911   0.260971  0.147690  0.164001
# TATACONSUM   0.172295    1.000000    0.188062   0.225777  0.271634  0.212756
# TATAMOTORS   0.305911    0.188062    1.000000   0.513416  0.248889  0.279026
# TATASTEEL    0.260971    0.225777    0.513416   1.000000  0.235867  0.283648
# TCS          0.147690    0.271634    0.248889   0.235867  1.000000  0.578882
# TECHM        0.164001    0.212756    0.279026   0.283648  0.578882  1.000000
# TITAN        0.214335    0.311262    0.274323   0.293416  0.145475  0.243389
# TRENT        0.256380    0.185995    0.222437   0.218748  0.122021  0.150751
# ULTRACEMCO   0.232441    0.244972    0.353946   0.471722  0.238679  0.269904
# WIPRO        0.192644    0.249107    0.311797   0.331808  0.591427  0.599253
#
# Ticker         TITAN     TRENT  ULTRACEMCO     WIPRO
# Ticker
# ADANIENT    0.283281  0.190412    0.361152  0.224003
# ADANIPORTS  0.296148  0.201076    0.402489  0.238986
# APOLLOHOSP  0.253361  0.089516    0.272951  0.223738
# ASIANPAINT  0.307404  0.223094    0.280647  0.140642
# AXISBANK    0.145931  0.199748    0.397024  0.207802
# BAJAJFINSV  0.329527  0.201133    0.463107  0.306650
# BAJAJ_AUTO  0.201060  0.223399    0.263342  0.102492
# BAJFINANCE  0.269039  0.229188    0.434558  0.238516
# BEL         0.166767  0.263415    0.435501  0.255854
# BHARTIARTL  0.276037  0.247927    0.354121  0.259131
# BPCL        0.275086  0.212755    0.401651  0.211945
# BRITANNIA   0.073109  0.034251    0.181814  0.169110
# CIPLA       0.107529  0.136473    0.133328  0.087595
# COALINDIA   0.238336  0.254629    0.321221  0.235794
# DRREDDY     0.139991  0.168870    0.251558  0.279839
# EICHERMOT   0.268206  0.234639    0.304244  0.262235
# GRASIM      0.368297  0.241469    0.590116  0.245002
# HCLTECH     0.199441  0.207422    0.205442  0.580667
# HDFCBANK    0.188021  0.102739    0.360209  0.193599
# HDFCLIFE    0.226622  0.202129    0.241819  0.194261
# HEROMOTOCO  0.302480  0.218545    0.295383  0.204583
# HINDALCO    0.249438  0.268630    0.313590  0.262244
# HINDUNILVR  0.187477  0.083964    0.165126  0.185425
# ICICIBANK   0.146474  0.121659    0.430208  0.221655
# INDUSINDBK  0.240433  0.199126    0.345066  0.186573
# INFY        0.215072  0.150991    0.224565  0.571208
# ITC         0.318261  0.151491    0.260144  0.233139
# JSWSTEEL    0.322128  0.256977    0.546643  0.360374
# KOTAKBANK   0.168053  0.081005    0.334770  0.245812
# LT          0.231900  0.185279    0.473174  0.319899
# M&M         0.285280  0.249013    0.418644  0.299971
# MARUTI      0.332279  0.183321    0.349174  0.205206
# NESTLEIND   0.236875  0.136674    0.278184  0.149708
# NTPC        0.334051  0.235736    0.448524  0.202935
# ONGC        0.192695  0.211585    0.404519  0.288967
# POWERGRID   0.208609  0.200542    0.396684  0.166631
# RELIANCE    0.329323  0.282779    0.490382  0.364313
# SBILIFE     0.219543  0.170800    0.266797  0.246338
# SBIN        0.223221  0.276491    0.425494  0.243531
# SHRIRAMFIN  0.254687  0.228691    0.468239  0.298607
# SUNPHARMA   0.214335  0.256380    0.232441  0.192644
# TATACONSUM  0.311262  0.185995    0.244972  0.249107
# TATAMOTORS  0.274323  0.222437    0.353946  0.311797
# TATASTEEL   0.293416  0.218748    0.471722  0.331808
# TCS         0.145475  0.122021    0.238679  0.591427
# TECHM       0.243389  0.150751    0.269904  0.599253
# TITAN       1.000000  0.194346    0.353920  0.259623
# TRENT       0.194346  1.000000    0.295226  0.150452
# ULTRACEMCO  0.353920  0.295226    1.000000  0.291504
# WIPRO       0.259623  0.150452    0.291504  1.000000
#
# [50 rows x 50 columns]

# %%
# Heatmap Visualization
import seaborn as sns
import matplotlib.pyplot as plt

# Set the size of the plot
plt.figure(figsize=(20,20))
# Create a heatmap using seaborn
sns.heatmap(correlation_matrix, annot=True, fmt=".2f", cmap='coolwarm', square=True, cbar_kws={"shrink": .8})
plt.title("Correlation Matrix of Daily Percentage Changes")
plt.tight_layout()
plt.show()

# %%
# Top Gainers and Losers Analysis
# This analysis is based on the top gainers and losers in the stock market
# The analysis is based on the percentage change in the stock price over a certain period of time
# This helps in identifying the stocks that have performed well and those that have underperformed during the October 3, 2023, 05:30 and November 22, 2024, 05:30 

import pandas as pd

# Read the stock data (assuming combined_data contains 'Date', 'Ticker', and 'Close' columns)
combined_data = pd.read_csv("Combined_Data.csv")

# Ensure the Date column is in datetime format, including the time
combined_data['date'] = pd.to_datetime(combined_data['date'])

# Filter the data between 3-October-2023 and 22-November-2024
start_date = pd.to_datetime('2023-10-03 05:30:00')
end_date = pd.to_datetime('2024-11-22 05:30:00')

# Filter the dataset for the desired date range
filtered_data = combined_data[(combined_data['date'] >= start_date) & (combined_data['date'] <= end_date)]

# Set Date as the index
filtered_data.set_index('date', inplace=True)

# Pivot the data to get stock prices for each ticker by date
stock_data = filtered_data.pivot(columns='Ticker', values='close')

# Calculate monthly returns (percentage change) by resampling and removing time from the Date
monthly_returns = stock_data.resample('ME').ffill().pct_change() * 100

# Drop columns or rows with all NaN values to clean the data
monthly_returns_cleaned = monthly_returns.dropna(how='all', axis=1)  # Drop columns where all values are NaN
monthly_returns_cleaned = monthly_returns_cleaned.dropna(how='all', axis=0)  # Drop rows where all values are NaN

# Calculate the cumulative returns for each stock over the entire period
cumulative_returns = (1 + monthly_returns_cleaned / 100).cumprod() - 1

# Get the final cumulative returns (last row for each stock)
final_returns = cumulative_returns.iloc[-1]

# Replace NaN values with 0 for stocks that didn't have any data
final_returns = final_returns.fillna(0)

# Sort the cumulative returns to get top gainers and losers
top_gainers = final_returns.sort_values(ascending=False).head(10)  # Top 10 gainers
top_losers = final_returns.sort_values(ascending=True).head(10)  # Top 10 losers

# Create DataFrame with "Ticker" and "Top Gainers"/"Top Losers"
top_gainers_df = pd.DataFrame({'Ticker': top_gainers.index, 'Top Gainers': top_gainers.values})
top_losers_df = pd.DataFrame({'Ticker': top_losers.index, 'Top Losers': top_losers.values})

# Display the results
print("Top 10 Gainers:")
print(top_gainers_df)

print("\nTop 10 Losers:")
print(top_losers_df)

# Save the results to CSV files
top_gainers_df.to_csv("Top_Gainers.csv", index=False)
top_losers_df.to_csv("Top_Losers.csv", index=False)
# Out:
# Top 10 Gainers:
#        Ticker  Top Gainers
# 0       TRENT     2.138483
# 1         BEL     1.128458
# 2         M&M     1.011584
# 3  BAJAJ-AUTO     0.785991
# 4  BHARTIARTL     0.694251
# 5   POWERGRID     0.677620
# 6        BPCL     0.648025
# 7   SUNPHARMA     0.609846
# 8        NTPC     0.557758
# 9       TECHM     0.550670
#
# Top 10 Losers:
#        Ticker  Top Losers
# 0  INDUSINDBK   -0.313787
# 1  ASIANPAINT   -0.166796
# 2  BAJFINANCE   -0.109169
# 3   NESTLEIND   -0.070276
# 4    ADANIENT   -0.030925
# 5  HINDUNILVR   -0.013575
# 6  BAJAJFINSV    0.025463
# 7   KOTAKBANK    0.025590
# 8       TITAN    0.061689
# 9      MARUTI    0.064043

# %%
# Top Gainers and Losers Analysis Month wise
import pandas as pd

# Read the stock data (assuming combined_data contains 'Date', 'Ticker', and 'Close' columns)
combined_data = pd.read_csv("Combined_Data.csv")

# Ensure the Date column is in datetime format, including the time
combined_data['date'] = pd.to_datetime(combined_data['date'])

# Filter the data between 3-October-2023 and 22-November-2024
start_date = pd.to_datetime('2023-10-03 05:30:00')
end_date = pd.to_datetime('2024-11-22 05:30:00')

# Filter the dataset for the desired date range
filtered_data = combined_data[(combined_data['date'] >= start_date) & (combined_data['date'] <= end_date)]

# Set Date as the index
filtered_data.set_index('date', inplace=True)

# Pivot the data to get stock prices for each ticker by date
stock_data = filtered_data.pivot(columns='Ticker', values='close')

# Calculate monthly returns (percentage change) by resampling and removing time from the Date
monthly_returns = stock_data.resample('ME').ffill().pct_change() * 100

# Drop columns or rows with all NaN values to clean the data
monthly_returns_cleaned = monthly_returns.dropna(how='all', axis=1)  # Drop columns where all values are NaN
monthly_returns_cleaned = monthly_returns_cleaned.dropna(how='all', axis=0)  # Drop rows where all values are NaN

# Loop through each month to calculate the top gainers and losers
for month, month_data in monthly_returns_cleaned.iterrows():
    # Calculate the cumulative returns for each stock over the current month
    monthly_final_returns = (1 + month_data / 100).cumprod() - 1
    
    # Replace NaN values with 0 for stocks that didn't have any data in that month
    monthly_final_returns = monthly_final_returns.fillna(0)

    # Sort the cumulative returns to get top gainers and losers for the current month
    top_gainers = monthly_final_returns.sort_values(ascending=False).head(10)  # Top 10 gainers
    top_losers = monthly_final_returns.sort_values(ascending=True).head(10)  # Top 10 losers

    # Create DataFrame with "Ticker", "Top Gainers"/"Top Losers", and the respective month
    top_gainers_df = pd.DataFrame({'Ticker': top_gainers.index, 'Top Gainers': top_gainers.values})
    top_losers_df = pd.DataFrame({'Ticker': top_losers.index, 'Top Losers': top_losers.values})

    # Add the month to the DataFrames
    top_gainers_df['Month'] = month.strftime('%B %Y')
    top_losers_df['Month'] = month.strftime('%B %Y')

    # Display the results for this month
    print(f"Top 10 Gainers for {month.strftime('%B %Y')}:")
    print(top_gainers_df)

    print(f"\nTop 10 Losers for {month.strftime('%B %Y')}:")
    print(top_losers_df)

    # Save the results to CSV files for the current month
    top_gainers_df.to_csv(f"D:/Topstocks/Top_Gainers_{month.strftime('%B_%Y')}.csv", index=False)
    top_losers_df.to_csv(f"D:/Bottomstocks/Top_Losers_{month.strftime('%B_%Y')}.csv", index=False)

print("Analysis complete. CSV files for each month are saved.")
# Out:
# Top 10 Gainers for November 2023:
#        Ticker  Top Gainers          Month
# 0       WIPRO    26.681900  November 2023
# 1  ULTRACEMCO    25.029504  November 2023
# 2       TRENT    24.042453  November 2023
# 3       TITAN    18.834008  November 2023
# 4       TECHM    17.024581  November 2023
# 5         TCS    15.625931  November 2023
# 6   TATASTEEL    14.986208  November 2023
# 7  TATAMOTORS    13.910033  November 2023
# 8  TATACONSUM    12.154988  November 2023
# 9   SUNPHARMA    11.591319  November 2023
#
# Top 10 Losers for November 2023:
#        Ticker  Top Losers          Month
# 0    ADANIENT    0.042408  November 2023
# 1  ADANIPORTS    0.109534  November 2023
# 2  APOLLOHOSP    0.242492  November 2023
# 3  ASIANPAINT    0.318392  November 2023
# 4    AXISBANK    0.412953  November 2023
# 5  BAJAJ-AUTO    0.615505  November 2023
# 6  BAJFINANCE    0.626071  November 2023
# 7  BAJAJFINSV    0.711125  November 2023
# 8         BEL    0.737598  November 2023
# 9  BHARTIARTL    0.867319  November 2023
# Top 10 Gainers for December 2023:
#        Ticker  Top Gainers          Month
# 0       WIPRO    71.050192  December 2023
# 1  ULTRACEMCO    61.105645  December 2023
# 2       TRENT    50.637920  December 2023
# 3       TITAN    44.239277  December 2023
# 4       TECHM    41.209539  December 2023
# 5         TCS    39.519698  December 2023
# 6   TATASTEEL    36.532580  December 2023
# 7  TATAMOTORS    33.346613  December 2023
# 8  TATACONSUM    30.369715  December 2023
# 9   SUNPHARMA    25.946231  December 2023
#
# Top 10 Losers for December 2023:
#        Ticker  Top Losers          Month
# 0    ADANIENT    0.188747  December 2023
# 1  ADANIPORTS    0.457354  December 2023
# 2  APOLLOHOSP    0.533193  December 2023
# 3  ASIANPAINT    0.656911  December 2023
# 4    AXISBANK    0.722787  December 2023
# 5  BAJAJ-AUTO    0.929211  December 2023
# 6  BAJAJFINSV    0.966897  December 2023
# 7  BAJFINANCE    1.021421  December 2023
# 8         BEL    1.640749  December 2023
# 9  BHARTIARTL    1.738378  December 2023
# Top 10 Gainers for January 2024:
#        Ticker  Top Gainers         Month
# 0       TITAN     0.665313  January 2024
# 1       TRENT     0.665313  January 2024
# 2       TECHM     0.638433  January 2024
# 3  TATAMOTORS     0.636710  January 2024
# 4       WIPRO     0.583811  January 2024
# 5         TCS     0.582237  January 2024
# 6  ULTRACEMCO     0.579788  January 2024
# 7   TATASTEEL     0.579261  January 2024
# 8     DRREDDY     0.571860  January 2024
# 9   COALINDIA     0.560275  January 2024
#
# Top 10 Losers for January 2024:
#        Ticker  Top Losers         Month
# 0   NESTLEIND   -0.193180  January 2024
# 1        NTPC   -0.182030  January 2024
# 2      MARUTI   -0.139443  January 2024
# 3         M&M   -0.109120  January 2024
# 4   KOTAKBANK   -0.077244  January 2024
# 5          LT   -0.049164  January 2024
# 6    JSWSTEEL   -0.034487  January 2024
# 7        ONGC   -0.005910  January 2024
# 8  INDUSINDBK    0.031556  January 2024
# 9         ITC    0.046666  January 2024
# Top 10 Gainers for February 2024:
#        Ticker  Top Gainers          Month
# 0       WIPRO     4.967070  February 2024
# 1       TRENT     4.534211  February 2024
# 2  ULTRACEMCO     4.446090  February 2024
# 3         TCS     3.588102  February 2024
# 4       TECHM     3.476694  February 2024
# 5       TITAN     3.307669  February 2024
# 6   TATASTEEL     3.233436  February 2024
# 7  TATAMOTORS     3.051466  February 2024
# 8  TATACONSUM     2.631963  February 2024
# 9   SUNPHARMA     2.491861  February 2024
#
# Top 10 Losers for February 2024:
#        Ticker  Top Losers          Month
# 0    ADANIENT    0.041377  February 2024
# 1  ASIANPAINT    0.087084  February 2024
# 2    AXISBANK    0.107813  February 2024
# 3  BAJFINANCE    0.138557  February 2024
# 4  ADANIPORTS    0.139739  February 2024
# 5  APOLLOHOSP    0.149231  February 2024
# 6  BAJAJFINSV    0.194357  February 2024
# 7  BAJAJ-AUTO    0.198918  February 2024
# 8  BHARTIARTL    0.213954  February 2024
# 9         BEL    0.246111  February 2024
# Top 10 Gainers for March 2024:
#        Ticker  Top Gainers       Month
# 0   TATASTEEL     1.862576  March 2024
# 1       TRENT     1.781846  March 2024
# 2  ULTRACEMCO     1.766015  March 2024
# 3       TITAN     1.765499  March 2024
# 4         TCS     1.693940  March 2024
# 5   SUNPHARMA     1.658030  March 2024
# 6       TECHM     1.614851  March 2024
# 7    RELIANCE     1.603284  March 2024
# 8  TATAMOTORS     1.585226  March 2024
# 9  SHRIRAMFIN     1.581432  March 2024
#
# Top 10 Losers for March 2024:
#        Ticker  Top Losers       Month
# 0    ADANIENT   -0.006803  March 2024
# 1    AXISBANK    0.017646  March 2024
# 2  APOLLOHOSP    0.024670  March 2024
# 3  ADANIPORTS    0.025564  March 2024
# 4  ASIANPAINT    0.043885  March 2024
# 5  BAJAJ-AUTO    0.136889  March 2024
# 6  BAJAJFINSV    0.179473  March 2024
# 7         BEL    0.288431  March 2024
# 8  BAJFINANCE    0.314967  March 2024
# 9     DRREDDY    0.352341  March 2024
# Top 10 Gainers for April 2024:
#        Ticker  Top Gainers       Month
# 0  ULTRACEMCO     0.758323  April 2024
# 1       TRENT     0.720331  April 2024
# 2       WIPRO     0.695513  April 2024
# 3       TECHM     0.660356  April 2024
# 4   TATASTEEL     0.611081  April 2024
# 5         TCS     0.608546  April 2024
# 6  SHRIRAMFIN     0.581694  April 2024
# 7       TITAN     0.574342  April 2024
# 8  TATAMOTORS     0.499922  April 2024
# 9        SBIN     0.497665  April 2024
#
# Top 10 Losers for April 2024:
#        Ticker  Top Losers       Month
# 0  BAJFINANCE   -0.132332  April 2024
# 1  APOLLOHOSP   -0.111733  April 2024
# 2  ASIANPAINT   -0.105040  April 2024
# 3  BAJAJFINSV   -0.079121  April 2024
# 4  ADANIPORTS   -0.053920  April 2024
# 5  BAJAJ-AUTO   -0.051304  April 2024
# 6    ADANIENT   -0.036252  April 2024
# 7    AXISBANK   -0.009279  April 2024
# 8         BEL    0.013643  April 2024
# 9       CIPLA    0.038058  April 2024
# Top 10 Gainers for May 2024:
#        Ticker  Top Gainers     Month
# 0         M&M     0.946951  May 2024
# 1      MARUTI     0.932858  May 2024
# 2   NESTLEIND     0.851995  May 2024
# 3        NTPC     0.835159  May 2024
# 4   POWERGRID     0.804734  May 2024
# 5  HINDUNILVR     0.762435  May 2024
# 6    RELIANCE     0.755238  May 2024
# 7        ONGC     0.728238  May 2024
# 8     SBILIFE     0.703038  May 2024
# 9        SBIN     0.701698  May 2024
#
# Top 10 Losers for May 2024:
#        Ticker  Top Losers     Month
# 0  BAJFINANCE    0.009972  May 2024
# 1    ADANIENT    0.036690  May 2024
# 2  BAJAJFINSV    0.042050  May 2024
# 3  APOLLOHOSP    0.051996  May 2024
# 4  ASIANPAINT    0.057681  May 2024
# 5    AXISBANK    0.065619  May 2024
# 6  ADANIPORTS    0.088830  May 2024
# 7  BAJAJ-AUTO    0.090970  May 2024
# 8       TITAN    0.119275  May 2024
# 9       WIPRO    0.128071  May 2024
# Top 10 Gainers for June 2024:
#        Ticker  Top Gainers      Month
# 0       WIPRO    20.065405  June 2024
# 1  ULTRACEMCO    16.878079  June 2024
# 2       TRENT    14.121494  June 2024
# 3       TITAN    11.835271  June 2024
# 4       TECHM    11.336256  June 2024
# 5         TCS     9.701886  June 2024
# 6   TATASTEEL     9.241235  June 2024
# 7  TATAMOTORS     8.660931  June 2024
# 8  TATACONSUM     8.018659  June 2024
# 9   SUNPHARMA     7.770059  June 2024
#
# Top 10 Losers for June 2024:
#        Ticker  Top Losers      Month
# 0    ADANIENT   -0.005353  June 2024
# 1  ADANIPORTS    0.062658  June 2024
# 2  APOLLOHOSP    0.139918  June 2024
# 3  ASIANPAINT    0.153102  June 2024
# 4    AXISBANK    0.249165  June 2024
# 5  BAJAJ-AUTO    0.323424  June 2024
# 6  BAJAJFINSV    0.379040  June 2024
# 7  BAJFINANCE    0.483066  June 2024
# 8         BEL    0.560880  June 2024
# 9        BPCL    0.589992  June 2024
# Top 10 Gainers for July 2024:
#        Ticker  Top Gainers      Month
# 0       WIPRO     8.347672  July 2024
# 1  ULTRACEMCO     8.228474  July 2024
# 2       TRENT     8.120177  July 2024
# 3       TITAN     7.891949  July 2024
# 4       TECHM     7.727737  July 2024
# 5         TCS     7.116588  July 2024
# 6  TATAMOTORS     6.698852  July 2024
# 7   TATASTEEL     6.259069  July 2024
# 8  TATACONSUM     5.558453  July 2024
# 9   SUNPHARMA     4.949646  July 2024
#
# Top 10 Losers for July 2024:
#        Ticker  Top Losers      Month
# 0    ADANIENT   -0.015234  July 2024
# 1  ADANIPORTS    0.030170  July 2024
# 2  BAJFINANCE    0.051928  July 2024
# 3    AXISBANK    0.053588  July 2024
# 4  BAJAJ-AUTO    0.060541  July 2024
# 5         BEL    0.093881  July 2024
# 6  BAJAJFINSV    0.096935  July 2024
# 7  APOLLOHOSP    0.105996  July 2024
# 8  BHARTIARTL    0.113804  July 2024
# 9  ASIANPAINT    0.139361  July 2024
# Top 10 Gainers for August 2024:
#        Ticker  Top Gainers        Month
# 0       TRENT     1.971207  August 2024
# 1       WIPRO     1.936403  August 2024
# 2  ULTRACEMCO     1.844232  August 2024
# 3       TITAN     1.332763  August 2024
# 4  TATACONSUM     1.295759  August 2024
# 5   SUNPHARMA     1.285716  August 2024
# 6       TECHM     1.269359  August 2024
# 7  TATAMOTORS     1.195973  August 2024
# 8    JSWSTEEL     1.143724  August 2024
# 9   KOTAKBANK     1.137363  August 2024
#
# Top 10 Losers for August 2024:
#        Ticker  Top Losers        Month
# 0  ADANIPORTS   -0.075128  August 2024
# 1  APOLLOHOSP   -0.035228  August 2024
# 2    ADANIENT   -0.034966  August 2024
# 3  ASIANPAINT    0.003860  August 2024
# 4    AXISBANK    0.008365  August 2024
# 5  BAJAJ-AUTO    0.148291  August 2024
# 6         BEL    0.237489  August 2024
# 7  BAJAJFINSV    0.246437  August 2024
# 8  BAJFINANCE    0.315220  August 2024
# 9  BHARTIARTL    0.337390  August 2024
# Top 10 Gainers for September 2024:
#        Ticker  Top Gainers           Month
# 0       WIPRO     5.405500  September 2024
# 1  ULTRACEMCO     5.365303  September 2024
# 2       TRENT     5.018927  September 2024
# 3  TATACONSUM     4.668408  September 2024
# 4   SUNPHARMA     4.661804  September 2024
# 5   TATASTEEL     4.521976  September 2024
# 6       TITAN     4.500337  September 2024
# 7  SHRIRAMFIN     4.292669  September 2024
# 8         TCS     4.224823  September 2024
# 9       TECHM     4.137822  September 2024
#
# Top 10 Losers for September 2024:
#        Ticker  Top Losers           Month
# 0  ADANIPORTS    0.019116  September 2024
# 1    ADANIENT    0.036746  September 2024
# 2  APOLLOHOSP    0.064206  September 2024
# 3  ASIANPAINT    0.126813  September 2024
# 4    AXISBANK    0.220678  September 2024
# 5  BAJAJ-AUTO    0.419596  September 2024
# 6  BAJAJFINSV    0.600842  September 2024
# 7         BEL    0.690722  September 2024
# 8  BAJFINANCE    0.724427  September 2024
# 9  BHARTIARTL    0.845585  September 2024
# Top 10 Gainers for October 2024:
#        Ticker  Top Gainers         Month
# 0    ADANIENT    -0.051433  October 2024
# 1  ADANIPORTS    -0.090829  October 2024
# 2  APOLLOHOSP    -0.122437  October 2024
# 3  ASIANPAINT    -0.205694  October 2024
# 4    AXISBANK    -0.269799  October 2024
# 5  BAJAJ-AUTO    -0.426935  October 2024
# 6  BAJAJFINSV    -0.500538  October 2024
# 7  BAJFINANCE    -0.552120  October 2024
# 8         BEL    -0.559599  October 2024
# 9  BHARTIARTL    -0.585305  October 2024
#
# Top 10 Losers for October 2024:
#        Ticker  Top Losers         Month
# 0  ULTRACEMCO   -0.990410  October 2024
# 1       WIPRO   -0.989995  October 2024
# 2       TRENT   -0.989770  October 2024
# 3       TITAN   -0.988950  October 2024
# 4         TCS   -0.987825  October 2024
# 5       TECHM   -0.987253  October 2024
# 6   TATASTEEL   -0.987158  October 2024
# 7  TATAMOTORS   -0.985642  October 2024
# 8  TATACONSUM   -0.983031  October 2024
# 9   SUNPHARMA   -0.980064  October 2024
# Top 10 Gainers for November 2024:
#        Ticker  Top Gainers          Month
# 0    ADANIENT    -0.249655  November 2024
# 1  ADANIPORTS    -0.389088  November 2024
# 2  APOLLOHOSP    -0.393235  November 2024
# 3  ASIANPAINT    -0.499427  November 2024
# 4    AXISBANK    -0.511402  November 2024
# 5  BAJAJ-AUTO    -0.533963  November 2024
# 6  BAJAJFINSV    -0.574278  November 2024
# 7  BAJFINANCE    -0.590869  November 2024
# 8         BEL    -0.601787  November 2024
# 9  BHARTIARTL    -0.617403  November 2024
#
# Top 10 Losers for November 2024:
#        Ticker  Top Losers          Month
# 0       TRENT   -0.855539  November 2024
# 1   TATASTEEL   -0.853884  November 2024
# 2  ULTRACEMCO   -0.853345  November 2024
# 3       WIPRO   -0.851684  November 2024
# 4         TCS   -0.848162  November 2024
# 5  TATAMOTORS   -0.847549  November 2024
# 6       TECHM   -0.842530  November 2024
# 7       TITAN   -0.842518  November 2024
# 8  TATACONSUM   -0.838067  November 2024
# 9   SUNPHARMA   -0.824789  November 2024
# Analysis complete. CSV files for each month are saved.

# %%
import pandas as pd

# Load the combined stock data (ensure 'date', 'Ticker', 'close' columns exist)
combined_data = pd.read_csv("Combined_Data.csv")

# Convert 'date' to datetime format
combined_data['date'] = pd.to_datetime(combined_data['date'])

# Filter the data between specific dates (adjust as needed)
start_date = pd.to_datetime('2023-10-03 05:30:00')
end_date = pd.to_datetime('2024-11-22 05:30:00')
filtered_data = combined_data[(combined_data['date'] >= start_date) & (combined_data['date'] <= end_date)]

# Set date as index for resampling
filtered_data.set_index('date', inplace=True)

# Pivot: each Ticker becomes a column, rows are dates with closing prices
stock_data = filtered_data.pivot(columns='Ticker', values='close')

# Resample monthly (month-end), forward fill missing data, then compute % change
monthly_returns = stock_data.resample('M').ffill().pct_change() * 100

# Drop rows/columns with all NaNs
monthly_returns_cleaned = monthly_returns.dropna(how='all', axis=1).dropna(how='all', axis=0)

# Store monthly gainers and losers
all_months_data = []

for month, month_data in monthly_returns_cleaned.iterrows():
    # Replace NaNs with 0
    month_data = month_data.fillna(0)

    # Get Top 5 Gainers
    top_gainers = month_data.sort_values(ascending=False).head(5)
    top_gainers_df = pd.DataFrame({
        'Ticker': top_gainers.index,
        'monthly_return': top_gainers.values,
        'Month': month.strftime('%B %Y'),
        'Type': 'Gainer'
    })

    # Get Top 5 Losers
    top_losers = month_data.sort_values(ascending=True).head(5)
    top_losers_df = pd.DataFrame({
        'Ticker': top_losers.index,
        'monthly_return': top_losers.values,
        'Month': month.strftime('%B %Y'),
        'Type': 'Loser'
    })

    # Append both to final list
    all_months_data.extend([top_gainers_df, top_losers_df])

# Combine everything into one DataFrame
final_df = pd.concat(all_months_data, ignore_index=True)

# Save to CSV
output_path = "D:/Myproject2/Top_Gainers_Losers_Monthwise.csv"
final_df.to_csv(output_path, index=False)

print(f"Monthly Top 5 Gainers and Losers saved to: {output_path}")
# Out:
# C:\Users\ASHWINI MURALIDHARAN\AppData\Local\Temp\ipykernel_62748\2335677518.py:21: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   monthly_returns = stock_data.resample('M').ffill().pct_change() * 100
# Monthly Top 5 Gainers and Losers saved to: D:/Myproject2/Top_Gainers_Losers_Monthwise.csv

# %%
# Top 10 Green and Red Stocks Analysis
import pandas as pd

# Assuming `combined_data` contains 'Date', 'Ticker', 'Close', and 'Volume' columns
combined_data = pd.read_csv("Combined_Data.csv")

# Ensure the Date column is in datetime format
combined_data['date'] = pd.to_datetime(combined_data['date'])

# Set Date as the index
combined_data.set_index('date', inplace=True)

# Pivot the data to get stock prices for each ticker by date
stock_data = combined_data.pivot(columns='Ticker', values='close')

# Calculate the yearly returns for each stock (using resampling)
yearly_returns = stock_data.resample('YE').ffill().pct_change() * 100

# Drop rows with NaN values for cleaner data
yearly_returns_cleaned = yearly_returns.dropna(how='all')

# Sort the yearly returns to get the top 10 gainers (green stocks) and top 10 losers (red stocks)
top_10_green_stocks = yearly_returns_cleaned.iloc[-1].sort_values(ascending=False).head(10)
top_10_red_stocks = yearly_returns_cleaned.iloc[-1].sort_values(ascending=True).head(10)

# Create DataFrames for Top 10 Green and Top 10 Red Stocks
top_10_green_df = pd.DataFrame({'Ticker': top_10_green_stocks.index, 'Yearly Return Percentage': top_10_green_stocks.values})
top_10_red_df = pd.DataFrame({'Ticker': top_10_red_stocks.index, 'Yearly Return Percentage': top_10_red_stocks.values})

# Market Summary Calculations
# 1. Number of Green vs. Red Stocks (Green = Positive Yearly Return, Red = Negative Yearly Return)
green_stocks_count = len(top_10_green_stocks)
red_stocks_count = len(top_10_red_stocks)

# 2. Average price across all stocks (mean of final closing prices)
average_price = stock_data.iloc[-1].mean()

# 3. Average Volume across all stocks (assuming 'Volume' column exists in combined_data)
volume_data = combined_data.pivot(columns='Ticker', values='volume')  # Pivot to get Volume data
average_volume = volume_data.iloc[-1].mean()

# Display the results
print("Top 10 Green Stocks (Gainers):")
print(top_10_green_df)

print("\nTop 10 Red Stocks (Losers):")
print(top_10_red_df)

print("\nMarket Summary:")
print(f"Number of Green Stocks: {green_stocks_count}")
print(f"Number of Red Stocks: {red_stocks_count}")
print(f"Average Price Across All Stocks: {average_price:.2f}")
print(f"Average Volume Across All Stocks: {average_volume:.2f}")

# Save the results to CSV files
top_10_green_df.to_csv("Top_10_Green_Stocks.csv", index=False)
top_10_red_df.to_csv("Top_10_Red_Stocks.csv", index=False)
# Out:
# Top 10 Green Stocks (Gainers):
#        Ticker  Yearly Return Percentage
# 0       TRENT                117.771158
# 1         M&M                 74.219382
# 2         BEL                 52.470141
# 3  BHARTIARTL                 52.034489
# 4   SUNPHARMA                 42.546350
# 5   POWERGRID                 42.053120
# 6  BAJAJ-AUTO                 39.492442
# 7  SHRIRAMFIN                 38.803390
# 8       TECHM                 37.307979
# 9     HCLTECH                 29.486392
#
# Top 10 Red Stocks (Losers):
#        Ticker  Yearly Return Percentage
# 0  INDUSINDBK                -37.571531
# 1  ASIANPAINT                -27.339525
# 2    ADANIENT                -21.795749
# 3   NESTLEIND                -15.452422
# 4  TATACONSUM                -11.948279
# 5       TITAN                 -9.978370
# 6   BRITANNIA                 -9.180567
# 7  BAJFINANCE                 -8.785780
# 8  HINDUNILVR                 -8.209614
# 9   KOTAKBANK                 -7.685656
#
# Market Summary:
# Number of Green Stocks: 10
# Number of Red Stocks: 10
# Average Price Across All Stocks: 2556.95
# Average Volume Across All Stocks: 7351255.78

# %%
# Green stocks are defined as stocks where the `close` price is greater than the `open` price. Red stocks are those where the `close` price is less than or equal to the `open` price.
# Positive stocks are defined as stocks with a `yearly_return` greater than 0, while negative stocks have a `yearly_return` less than or equal to 0.
# yearly return is calculated as (close - open) / open. This is a simple measure of return on investment
# The function should return a dictionary where the keys are the stock names and the values are the corresponding
import pandas as pd

df = pd.read_csv(r"D:\Myproject2\Combined_Data.csv")
#display(df)

# Finding yearly return to find top 10 green and red stocks 
df['yearly_return'] = (df['close'] - df['open']) / df['open']

# Top 10 Green Stocks
top_10_green_stocks = df.sort_values(by='yearly_return', ascending=False).head(10)
#print("Top 10 Green Stocks:")
#print(top_10_green_stocks)

# Top 10 Loss Stocks
top_10_loss_stocks = df.sort_values(by='yearly_return', ascending=True).head(10)
#print("\nTop 10 Loss Stocks:")
#print(top_10_loss_stocks)

# Merge the two dataframes to get the final result
# Create a new dataframe with the top 10 green and red stocks
Top10_gain_loss = pd.merge(top_10_green_stocks, top_10_loss_stocks)
# Print the final result
print("\nFinal Result:")

# Save the final result to a csv file
Top10_gain_loss.to_csv(r"D:\Myproject2\TopGainNLoss_Data.csv", index=False)

# Market Summary
# Calculate the overall number of green vs. red stocks
green_stocks = len(df[df['yearly_return'] > 0])
red_stocks = len(df[df['yearly_return'] <= 0])

# Calculate the average price across all stocks
average_price = df['close'].mean()

# Calculate the average volume across all stocks
average_volume = df['volume'].mean()

print("\nMarket Summary:")
print(f"Number of Green Stocks: {green_stocks}")
print(f"Number of Red Stocks: {red_stocks}")
print(f"Average Price Across All Stocks: {average_price:.2f}")
print(f"Average Volume Across All Stocks: {average_volume:.2f}")
# Out:
# Final Result:
#
# Market Summary:
# Number of Green Stocks: 6544
# Number of Red Stocks: 7656
# Average Price Across All Stocks: 2449.42
# Average Volume Across All Stocks: 6833474.65

# %%
import pandas as pd

# Load the CSV data
df = pd.read_csv(r"D:\Myproject2\Combined_Data.csv")

# Check the columns to confirm the necessary ones exist
# print(df.columns)  # Uncomment for debugging

# Calculate the yearly return: (close - open) / open
df['yearly_return'] = (df['close'] - df['open']) / df['open']

# Top 10 Green Stocks (where yearly_return > 0)
top_10_green_stocks = df[df['yearly_return'] > 0].sort_values(by='yearly_return', ascending=False).head(10)

# Top 10 Loss (Red) Stocks (where yearly_return <= 0)
top_10_loss_stocks = df[df['yearly_return'] <= 0].sort_values(by='yearly_return', ascending=True).head(10)

# Print top green and red stocks for debugging (Optional)
print("Top 10 Green Stocks:")
print(top_10_green_stocks[['Ticker', 'yearly_return', 'close', 'open']])

print("\nTop 10 Loss Stocks:")
print(top_10_loss_stocks[['Ticker', 'yearly_return', 'close', 'open']])

# Combine the two lists into a dictionary or separate list for visualization/analysis
top_10_gain_loss = {
    'Top 10 Green Stocks': top_10_green_stocks[['Ticker', 'yearly_return', 'close', 'open']],
    'Top 10 Loss Stocks': top_10_loss_stocks[['Ticker', 'yearly_return', 'close', 'open']]
}

# Print the result to confirm the data
print("\nFinal Result (Top 10 Green and Red Stocks):")
print(top_10_gain_loss)

# Optionally save the result to a CSV (or combine into one DataFrame and save)
top_10_combined = pd.concat([top_10_green_stocks[['Ticker', 'yearly_return', 'close', 'open']],
                              top_10_loss_stocks[['Ticker', 'yearly_return', 'close', 'open']]])

# Save the combined result to a CSV
top_10_combined.to_csv(r"D:\Myproject2\TopGainNLoss_Data.csv", index=False)

# Market Summary
# Calculate the overall number of green vs. red stocks
green_stocks = len(df[df['yearly_return'] > 0])
red_stocks = len(df[df['yearly_return'] <= 0])

# Calculate the average price across all stocks
average_price = df['close'].mean()

# Calculate the average volume across all stocks
average_volume = df['volume'].mean()

# Print the market summary
print("\nMarket Summary:")
print(f"Number of Green Stocks: {green_stocks}")
print(f"Number of Red Stocks: {red_stocks}")
print(f"Average Price Across All Stocks: {average_price:.2f}")
print(f"Average Volume Across All Stocks: {average_volume:.2f}")

# Combine No of Green and Red Stocks , Average Price and Average Volume into dataframe and save to csv file
market_summary = pd.DataFrame({'No of Green Stocks': [green_stocks],'No of Red Stocks': [red_stocks],'average_price': [average_price],'average_volume': [average_volume]})
market_summary.to_csv(r"D:\Myproject2\MarketSummary.csv", index=False)
# Out:
# Top 10 Green Stocks:
#            Ticker  yearly_return    close     open
# 4363        TRENT       0.171266  3607.50  3080.00
# 2174     ADANIENT       0.169149  2959.35  2531.20
# 2175   ADANIPORTS       0.146041  1013.10   884.00
# 8395     HINDALCO       0.108852   695.25   627.00
# 10613       TRENT       0.093486  6275.35  5738.85
# 1213        TRENT       0.084831  2424.00  2234.45
# 10138  SHRIRAMFIN       0.081011  2925.00  2705.80
# 4242         BPCL       0.079248   279.18   258.68
# 7924     ADANIENT       0.073051  3387.30  3156.70
# 8381   INDUSINDBK       0.071724  1500.95  1400.50
#
# Top 10 Loss Stocks:
#            Ticker  yearly_return    close     open
# 8325   ADANIPORTS      -0.198363  1248.95  1558.00
# 8326          BEL      -0.180929   255.55   312.00
# 8340         ONGC      -0.170877   236.30   285.00
# 8324     ADANIENT      -0.164418  2941.25  3520.00
# 8318         NTPC      -0.154759   331.25   391.90
# 14124    ADANIENT      -0.140075  2183.65  2539.35
# 8329    COALINDIA      -0.137504   441.90   512.35
# 8300         SBIN      -0.135786   775.20   897.00
# 8342         BPCL      -0.134030   290.10   335.00
# 8305           LT      -0.116511  3403.20  3852.00
#
# Final Result (Top 10 Green and Red Stocks):
# {'Top 10 Green Stocks':            Ticker  yearly_return    close     open
# 4363        TRENT       0.171266  3607.50  3080.00
# 2174     ADANIENT       0.169149  2959.35  2531.20
# 2175   ADANIPORTS       0.146041  1013.10   884.00
# 8395     HINDALCO       0.108852   695.25   627.00
# 10613       TRENT       0.093486  6275.35  5738.85
# 1213        TRENT       0.084831  2424.00  2234.45
# 10138  SHRIRAMFIN       0.081011  2925.00  2705.80
# 4242         BPCL       0.079248   279.18   258.68
# 7924     ADANIENT       0.073051  3387.30  3156.70
# 8381   INDUSINDBK       0.071724  1500.95  1400.50, 'Top 10 Loss Stocks':            Ticker  yearly_return    close     open
# 8325   ADANIPORTS      -0.198363  1248.95  1558.00
# 8326          BEL      -0.180929   255.55   312.00
# 8340         ONGC      -0.170877   236.30   285.00
# 8324     ADANIENT      -0.164418  2941.25  3520.00
# 8318         NTPC      -0.154759   331.25   391.90
# 14124    ADANIENT      -0.140075  2183.65  2539.35
# 8329    COALINDIA      -0.137504   441.90   512.35
# 8300         SBIN      -0.135786   775.20   897.00
# 8342         BPCL      -0.134030   290.10   335.00
# 8305           LT      -0.116511  3403.20  3852.00}
#
# Market Summary:
# Number of Green Stocks: 6544
# Number of Red Stocks: 7656
# Average Price Across All Stocks: 2449.42
# Average Volume Across All Stocks: 6833474.65
